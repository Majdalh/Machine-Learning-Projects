# %%
pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.2.0-cp38-cp38-win_amd64.whl (12.1 MB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp38-cp38-win_amd64.whl (113 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in c:\users\acc\anaconda3\lib\site-packages (from spacy) (1.19.2)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp38-cp38-win_amd64.whl (36 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\acc\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\acc\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in c:\users\acc\anaconda3\lib\site-packages (from spacy) (20.4)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp38-cp38-win_amd64.whl (452 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.5-cp38-cp38-win_amd64.whl (6.6 MB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp38-cp38-win_amd64.whl (21 kB)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in c:\users\acc\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in c:\users\acc\anaconda3\lib\site-packages (from spacy) (2.21.0)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Requirement already satisfied, skipping upgrade: click<9.0.0,>=7.1.1 in c:\users\acc\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\acc\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in c:\users\acc\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in c:\users\acc\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (1.12.0)
# Requirement already satisfied, skipping upgrade: smart-open<6.0.0,>=5.0.0 in c:\users\acc\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\acc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\acc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\acc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in c:\users\acc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.3 in c:\users\acc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Installing collected packages: wasabi, murmurhash, cymem, preshed, catalogue, typer, spacy-legacy, srsly, pathy, blis, pydantic, thinc, langcodes, spacy-loggers, spacy
# Successfully installed blis-0.7.5 catalogue-2.0.6 cymem-2.0.6 langcodes-3.3.0 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 spacy-3.2.0 spacy-legacy-3.0.8 spacy-loggers-1.0.1 srsly-2.4.2 thinc-8.0.13 typer-0.4.0 wasabi-0.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from spacy.cli.download import download
download(model="en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## loading the Libraries and the data

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import spacy  # For preprocessing
import gensim
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

# %%
df = pd.read_csv('simpsons_dataset.csv')
df.shape
# Out:
# (158314, 2)

# %%
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %%
df.isnull().sum()
# Out:
# raw_character_text    17814
# spoken_words          26459
# dtype: int64

# %% [markdown]
# ## Preprocessing the data:

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# raw_character_text    0
# spoken_words          0
# dtype: int64

# %%
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    txt = [token.lemma_ for token in doc if not token.is_stop]
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df['spoken_words'])

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_process=-1)]

print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 6.54 mins

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean=df_clean.reset_index(drop=True)

# %%
df_clean.head()
# Out:
#                                                clean
# 0  actually little disease magazine news show nat...
# 1        know sure like talk touch lesson plan teach
# 2                                    life worth live
# 3  poll open end recess case decide thought final...
# 4                                victory party slide

# %%
df_clean.shape
# Out:
# (85952, 1)

# %% [markdown]
# ## Tokenizing and creating a bigram content:

# %%
content=[gensim.utils.simple_preprocess(row) for row in df_clean['clean']]

# %%
content
# Out:
# [['actually',
#   'little',
#   'disease',
#   'magazine',
#   'news',
#   'show',
#   'natural',
#   'think'],
#  ['know', 'sure', 'like', 'talk', 'touch', 'lesson', 'plan', 'teach'],
#  ['life', 'worth', 'live'],
#  ['poll',
#   'open',
#   'end',
#   'recess',
#   'case',
#   'decide',
#   'thought',
#   'final',
#   'statement',
#   'martin'],
#  ['victory', 'party', 'slide'],
#  ['mr', 'bergstrom', 'mr', 'bergstrom'],
#  ['hey',
#   'hey',
#   'move',
#   'morning',
#   'new',
#   'job',
#   'take',
#   'copernicus',
#   'costume'],
#  ['think', 'take', 'train', 'capital', 'city'],
#  ['train', 'like', 'traditional', 'environmentally', 'sound'],
#  ['yes',
#   'backbone',
#   'country',
#   'leland',
#   'stanford',
#   'drive',
#   'golden',
#   'spike',
#   'promontory',
#   'point'],
#  ['hey', 'thank', 'vote', 'man'],
#  ['vote', 'voting', 'geek'],
#  ['get', 'right', 'thank', 'vote', 'girl'],
#  ['sweat', 'long', 'couple', 'people', 'right', 'milhouse'],
#  ['martin', 'martin', 'like', 'recount'],
#  ['want', 'sure', 'martin', 'martin'],
#  ['way', 'mister', 'president'],
#  ['board',
#   'track',
#   'afternoon',
#   'delight',
#   'come',
#   'shelbyville',
#   'parkville'],
#  ['mr', 'bergstrom', 'hey', 'mr', 'bergstrom'],
#  ['oh', 'mean', 'go', 'leave', 'like'],
#  ['ah',
#   'sorry',
#   'lisa',
#   'know',
#   'life',
#   'substitute',
#   'teacher',
#   'fraud',
#   'today',
#   'wear',
#   'gym',
#   'short',
#   'tomorrow',
#   'speak',
#   'french',
#   'pretend',
#   'know',
#   'run',
#   'band',
#   'see',
#   'god',
#   'know'],
#  ['ah', 'true', 'teacher', 'come'],
#  ['lie', 'good', 'know', 'need', 'project', 'capital', 'city'],
#  ['problem', 'middle', 'class', 'anybody', 'care', 'abandon', 'need'],
#  ['understand', 'mr', 'bergstrom', 'go', 'miss'],
#  ['feel', 'like', 'rely', 'need', 'know'],
#  ['thank', 'mr', 'bergstrom'],
#  ['guess', 'mind', 'run', 'alongside', 'train', 'speed', 'life'],
#  ['goodbye', 'lisa', 'honey', 'okay', 'read', 'note'],
#  ['throw', 'party', 'big', 'bash', 'champagne', 'musician', 'holy', 'man'],
#  ['bart',
#   'vote',
#   'oh',
#   'bad',
#   'thing',
#   'happen',
#   'alright',
#   'allright',
#   'spill',
#   'milk',
#   'spill',
#   'milk',
#   'spill',
#   'milk',
#   'mopey'],
#  ['lisa', 'tell', 'father'],
#  ['mr', 'bergstrom', 'leave', 'today'],
#  ['hey', 'care', 'mean', 'understand'],
#  ['glad', 'cry', 'hate', 'think', 'base', 'emotion', 'sir', 'baboon'],
#  ['yes', 'baboon', 'baboon', 'baboon', 'baboon'],
#  ['think', 'realize', 'say'],
#  ['whoa', 'somebody', 'bind', 'day', 'believe'],
#  ['hear', 'marge', 'call', 'baboon', 'stupidest', 'ugly', 'smelliest', 'ape'],
#  ['homer',
#   'allow',
#   'hurt',
#   'feeling',
#   'right',
#   'little',
#   'girl',
#   'upstairs',
#   'need',
#   'confidence',
#   'father',
#   'shake',
#   'little',
#   'girl',
#   'happy',
#   'faith',
#   'daddy'],
#  ['lisa', 'hold', 'tell', 'cry', 'call', 'daddy', 'baboon'],
#  ['look', 'want', 'forgive'],
#  ['maybe',
#   'help',
#   'lose',
#   'special',
#   'hurt',
#   'lucky',
#   'lose',
#   'special',
#   'special',
#   'roof'],
#  ['child', 'time', 'bed'],
#  ['true',
#   'lot',
#   'special',
#   'people',
#   'life',
#   'lisa',
#   'probably',
#   'place',
#   'food',
#   'real',
#   'good',
#   'guy',
#   'like',
#   'serve',
#   'drink',
#   'oh',
#   'maybe',
#   'explain',
#   'fix',
#   'doll',
#   'house',
#   'good',
#   'monkey',
#   'work',
#   'know',
#   'monkey',
#   'know',
#   'mean'],
#  ['hold', 'nail', 'place', 'tail'],
#  ['sorry', 'call', 'baboon', 'dad'],
#  ['hey', 'matter', 'son'],
#  ['ah', 'dad', 'milhouse', 'lewis', 'vote'],
#  ['hey', 'son', 'get', 'money', 'class', 'president'],
#  ['martin',
#   'guy',
#   'go',
#   'neat',
#   'like',
#   'throw',
#   'ball',
#   'world',
#   'series',
#   'huh'],
#  ['let', 'baby', 'bottle', 'huh', 'motto'],
#  ['hey', 'thank', 'monkey', 'man'],
#  ['holy', 'moly', 'talk', 'parent'],
#  ['sleep', 'maggie', 'ah'],
#  ['marge', 'let', 'bed', 'big', 'roll', 'life'],
#  ['mmm', 'hor', 'doover'],
#  ['promise', 'eat', 'lie'],
#  ['homer', 'throw', 'party', 'going', 'to', 'pay', 'friend', 'invite', 'home'],
#  ['mom', 'want', 'hear', 'witty', 'banter', 'sophisticated', 'adult'],
#  ['yeah', 'fun', 'bed'],
#  ['oh', 'son', 'old', 'know', 'well'],
#  ['hmmm', 'oh', 'baby', 'mmmm', 'yeah'],
#  ['gag', 'ice', 'cub'],
#  ['homer', 'homer', 'record'],
#  ['hey', 'anybody', 'mind', 'serve', 'bartender', 'know', 'ph', 'mixology'],
#  ['hey', 'homer', 'care', 'try', 'flander', 'planter', 'punch'],
#  ['hey', 'flander', 'time', 'little', 'alcohol'],
#  ['au',
#   'contraire',
#   'simpson',
#   'shot',
#   'rum',
#   'jigger',
#   'bourbon',
#   'little',
#   'dab',
#   'roo',
#   'creme',
#   'de',
#   'cassis',
#   'flavor'],
#  ['warm', 'sense', 'ssslurre', 'shpeech', 'right'],
#  ['homer',
#   'easy',
#   'al',
#   'ky',
#   'hol',
#   'remember',
#   'year',
#   'winfield',
#   'party',
#   'throw',
#   'laundry',
#   'hamper'],
#  ['hi',
#   'homer',
#   'sister',
#   'law',
#   'right',
#   'remember',
#   'remember',
#   'beau',
#   'tiful'],
#  ['ow', 'hey', 'jeez'],
#  ['new', 'kind', 'mace', 'painful'],
#  ['oh', 'dr', 'hibbert', 'enjoy', 'party'],
#  ['uh', 'slip', 'novelty', 'ice', 'cube', 'fake', 'fly', 'drink'],
#  ['homer',
#   'novelty',
#   'ice',
#   'cube',
#   'highly',
#   'toxic',
#   'chemical',
#   'ironically',
#   'real',
#   'fly',
#   'sanitary'],
#  ['look', 'face', 'priceless'],
#  ['little', 'monkey', 'little', 'monkey'],
#  ['bart', 'thing', 'cute'],
#  ['hey', 'everybody', 'look', 'funniest', 'guy', 'world'],
#  ['oh', 'homer', 'king'],
#  ['wantin', 'tell', 'year', 'nerve'],
#  ['homer', 'know', 'wife', 'wife', 'friend', 'meet', 'hour', 'ago'],
#  ['stink', 'lousy', 'operation', 'stink', 'quit'],
#  ['uh', 'gee', 'homer', 'quit'],
#  ['handful', 'peanut', 'maude'],
#  ['hey', 'thank', 'invitin', 'wonderful', 'time'],
#  ['want', 'live', 'night', 'suggest', 'roll'],
#  ['hmmm', 'thank', 'dr', 'hibbert', 'thank', 'come'],
#  ['want', 'sure', 'kid', 'hear', 'young', 'hate', 'know', 'parent', 'fight'],
#  ['music', 'send', 'chill', 'spine'],
#  ['homer', 'remember', 'way', 'act', 'party', 'night'],
#  ['say', 'wet', 'clothe', 'dry', 'martini'],
#  ['good', 'lord', 'fly', 'drink'],
#  ['slip', 'glass', 'gag'],
#  ['pronounce', 'whimsical', 'jape', 'season'],
#  ['homer',
#   'like',
#   'think',
#   'patient',
#   'tolerant',
#   'woman',
#   'line',
#   'cross',
#   'stop',
#   'love',
#   'night',
#   'cross',
#   'line',
#   'throw'],
#  ['sorry', 'honey', 'forget', 'church'],
#  ['go', 'church', 'today', 'go', 'stay', 'explain', 'bart', 'scar', 'life'],
#  ['oh', 'mean', 'inside'],
#  ['night',
#   'notice',
#   'daddy',
#   'act',
#   'little',
#   'strange',
#   'probably',
#   'understand'],
#  ['admit', 'know', 'sorry', 'happen', 'hope', 'lose', 'lot', 'respect'],
#  ['sneak',
#   'preview',
#   'week',
#   'sermon',
#   'announcement',
#   'new',
#   'pamphlet',
#   'available',
#   'church',
#   'newsrack',
#   'include',
#   'bible',
#   'baffler',
#   'satan',
#   'boner',
#   'good',
#   'grief',
#   'satan',
#   'boner',
#   'teen',
#   'cool',
#   'fry',
#   'hell'],
#  ['sorry',
#   'lord',
#   'compete',
#   'squeaking',
#   'homer',
#   'simpson',
#   'shoe',
#   'hold',
#   'take',
#   'seat'],
#  ['mrs',
#   'lovejoy',
#   'hold',
#   'annual',
#   'marriage',
#   'retreat',
#   'weekend',
#   'catfish',
#   'lake',
#   'psychological',
#   'counseling',
#   'couple',
#   'marriage',
#   'hang',
#   'thread'],
#  ['need', 'tune'],
#  ['wish', 'participate', 'sign', 'way', 'service'],
#  ['simpson', 'attend', 'little', 'retreat'],
#  ['oh', 'tempting', 'wonderful', 'idea'],
#  ['marriage', 'encounter', 'weekend', 'come'],
#  ['hold', 'catfish', 'lake', 'catfish', 'lake', 'catfish'],
#  ['go', 'retreat', 'marriage', 'tune', 'fishing'],
#  ['hello', 'mrs', 'simpson'],
#  ['oh', 'suppose', 'sitter', 'short', 'notice'],
#  ['oh', 'dear', 'find', 'babysitter', 'kick', 'tooth'],
#  ['need', 'babysitter', 'half'],
#  ['tone', 'young', 'lady', 'taste', 'hand'],
#  ['wonder', 'think', 'babysit', 'kid', 'weekend', 'ask', 'desperate'],
#  ['oh',
#   'sure',
#   'resort',
#   'old',
#   'grampa',
#   'feeb',
#   'guy',
#   'count',
#   'dagnabit',
#   'agin'],
#  ['marge', 'puttin', 'thing', 'trunk'],
#  ['maggie',
#   'run',
#   'fever',
#   'number',
#   'stick',
#   'finger',
#   'electrical',
#   'socket',
#   'number',
#   'drink',
#   'pine',
#   'cleanser'],
#  ['right', 'right', 'goodbye', 'child', 'behave'],
#  ['number', 'grampa', 'fall', 'bathtub'],
#  ['grampa', 'mom', 'hurry', 'forget', 'list', 'thing', 'lisa'],
#  ['uh', 'huh', 'uh', 'huh', 'allow', 'smoke', 'cigar'],
#  ['whoa', 'well', 'gas'],
#  ['fill', 'er', 'guess', 'stretch', 'leg'],
#  ['oh', 'general', 'sherman', 'ya'],
#  ['wait', 'wait', 'minute', 'wait', 'minute', 'general', 'sherman'],
#  ['big', 'catfish', 'part'],
#  ['weigh', 'upwards', 'pound'],
#  ['know', 'picture', 'general', 'exactly', 'freakishly', 'big'],
#  ['hmmmm', 'gentleman', 'go', 'catch', 'general', 'sherman'],
#  ['supermarket',
#   'video',
#   'store',
#   'grab',
#   'krusty',
#   'burger',
#   'head',
#   'arcade'],
#  ['bart',
#   'grampa',
#   'kindly',
#   'old',
#   'man',
#   'trust',
#   'sure',
#   'right',
#   'advantage'],
#  ['li',
#   'crazy',
#   'topsy',
#   'turvy',
#   'time',
#   'right',
#   'wrong',
#   'right',
#   'gut',
#   'tell',
#   'bleed',
#   'gramp',
#   'dry'],
#  ['ah', 'mr', 'mrs', 'simpson', 'welcome'],
#  ['hello', 'reverend', 'glad', 'come', 'oh', 'hello', 'helen'],
#  ['hel', 'lo', 'marge'],
#  ['homer', 'simpson', 'marriage', 'little', 'spit', 'shine'],
#  ['uh', 'uh', 'reverend', 'going', 'to', 'chance', 'fishing'],
#  ['oh', 'afraid', 'marriage', 'reconcile', 'hour', 'homer', 'take', 'weekend'],
#  ['bait',
#   'hook',
#   'honesty',
#   'way',
#   'happy',
#   'marriage',
#   'will',
#   'get',
#   'away'],
#  ['understand', 'bowling', 'expression'],
#  ['ah',
#   'couple',
#   'good',
#   'turnout',
#   'room',
#   'introduce',
#   'tell',
#   'little',
#   'bit',
#   'john',
#   'gloria'],
#  ['gloria',
#   'johnny',
#   'boy',
#   'able',
#   'cut',
#   'manwise',
#   'time',
#   'want',
#   'odor',
#   'gin',
#   'sour',
#   'defeat',
#   'press'],
#  ['thank', 'gloria', 'john', 'tell', 'little'],
#  ['cook', 'keep', 'filthy', 'house', 'talk', 'profanely', 'queen', 'harpy'],
#  ['come', 'right', 'place', 'want', 'look', 'eye'],
#  ['eye', 'forget', 'beautiful'],
#  ['remember',
#   'save',
#   'life',
#   'bring',
#   'happiness',
#   'pass',
#   'collection',
#   'plate',
#   'week',
#   'right',
#   'ned',
#   'maude',
#   'bring'],
#  ['maude', 'god', 'bless', 'underline', 'passage', 'bible', 'find'],
#  ['lucky', 'gun', 'house'],
#  ['ohhh', 'get', 'drunk', 'look', 'dress'],
#  ['homer', 'marge', 'go', 'tell', 'fault', 'tell'],
#  ['come', 'homer', 'fault'],
#  ['marge', 'interrupt', 'turn'],
#  ['love', 'guy', 'stick', 'self', 'center'],
#  ['forget',
#   'birthday',
#   'anniversary',
#   'holiday',
#   'religious',
#   'secular',
#   'chew',
#   'mouth',
#   'open',
#   'gamble',
#   'hang',
#   'seedy',
#   'bar',
#   'bum',
#   'lowlife'],
#  ['blow', 'nose', 'towel', 'put', 'middle'],
#  ['half', 'gallon', 'chocolate'],
#  ['half', 'gallon', 'chocolate', 'brownie', 'fudge'],
#  ['half',
#   'gallon',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chocolate',
#   'chip'],
#  ['mom', 'write', 'shopping', 'list'],
#  ['hey', 'grampa', 'aisle', 'step'],
#  ['drink',
#   'carton',
#   'change',
#   'baby',
#   'go',
#   'sleep',
#   'make',
#   'chew',
#   'noise',
#   'wake',
#   'make',
#   'honk',
#   'noise',
#   'oh',
#   'oh',
#   'scratch',
#   'key',
#   'guess',
#   'oh',
#   'wait',
#   'kick',
#   'sleep',
#   'toenail',
#   'long',
#   'yellow',
#   'think',
#   'right',
#   'guess',
#   'tired',
#   'want',
#   'thank',
#   'let',
#   'thing',
#   'chest'],
#  ['miss', 'luau', 'night'],
#  ['want', 'hear', 'mcbain', 'cannon', 'regulation', 'department', 'book'],
#  ['know', 'kid', 'gettin', 'pretty', 'late'],
#  ['yeah', 'bed', 'grampa', 'big', 'day'],
#  ['use', 'kid', 'have', 'ethical', 'crisis'],
#  ['catch',
#   'general',
#   'sherman',
#   'thirty',
#   'clean',
#   'eat',
#   'thirty',
#   'bed',
#   'seven',
#   'incriminate',
#   'evidence',
#   'perfect',
#   'crime'],
#  ['homer',
#   'sneak',
#   'fish',
#   'believe',
#   'selfishness',
#   'fishing',
#   'anytime',
#   'try',
#   'save',
#   'marriage',
#   'think',
#   'fish',
#   'talk',
#   'right',
#   'right'],
#  ['good', 'time', 'honest'],
#  ['right', 'help', 'marge', 'good', 'guy'],
#  ['right', 'sleep', 'walk'],
#  ['got',
#   'to',
#   'good',
#   'husband',
#   'got',
#   'to',
#   'good',
#   'husband',
#   'got',
#   'to',
#   'good',
#   'husband'],
#  ['hey', 'kid', 'forgot', 'whoa'],
#  ['ahead',
#   'general',
#   'sherman',
#   'waste',
#   'strength',
#   'big',
#   'ugly',
#   'catfish',
#   'got',
#   'to',
#   'skillet',
#   'stick',
#   'butter'],
#  ['sure', 'ma', 'let', 'kid', 'drink', 'coffee'],
#  ['hey',
#   'milhouse',
#   'big',
#   'blowout',
#   'casa',
#   'de',
#   'simpson',
#   'adult',
#   'frail',
#   'old'],
#  ['bart', 'joint', 'uh', 'twoish', 'square'],
#  ['tell', 'friend', 'right', 'get', 'pretty', 'funky', 'friend'],
#  ['right', 'noon', 'invite', 'party'],
#  ['trust', 'exercise', 'fall', 'backwards', 'rely', 'spouse', 'catch'],
#  ['husband',
#   'recommend',
#   'marge',
#   'train',
#   'marriage',
#   'counselor',
#   'instance',
#   'tell',
#   'partner',
#   'percent',
#   'right',
#   'fault',
#   'willing',
#   'certificate',
#   'frame'],
#  ['send', 'word', 'send', 'word'],
#  ['yank', 'comin'],
#  ['okay',
#   'fish',
#   'probably',
#   'wonder',
#   'catch',
#   'famous',
#   'fisherman',
#   'right',
#   'bald',
#   'guy',
#   'cable',
#   'fishing'],
#  ['whoa', 'holy', 'mackerel'],
#  ['milhouse', 'good', 'pal', 'happen', 'man'],
#  ['cherry', 'party', 'bart', 'chick'],
#  ['obvious', 'degrade', 'set', 'child', 'right', 'movement', 'decade', 'come'],
#  ['great', 'party', 'lisa', 'great'],
#  ['hey', 'shut', 'door', 'stop', 'away', 'stop', 'oh'],
#  ['haw', 'haw', 'haw'],
#  ['young', 'hellion', 'want', 'belt'],
#  ['yeah',
#   'care',
#   'man',
#   'hey',
#   'thank',
#   'come',
#   'hey',
#   'nice',
#   'tie',
#   'nelson'],
#  ['ah', 'thank', 'dad'],
#  ['try', 'good', 'baby', 'sitter', 'fail', 'feeb', 'useless', 'old', 'wear'],
#  ['lisa', 'strong', 'unpleasant', 'feeling'],
#  ['call', 'remorse', 'vile', 'burlesque', 'irrepressible', 'youth'],
#  ['grab', 'bucket', 'brush', 'clean', 'hard', 'fast'],
#  ['champion', 'champion', 'time', 'loser', 'cause', 'champion', 'worlllld'],
#  ['hi', 'honey', 'uh', 'oh', 'marriage', 'retreat', 'go'],
#  ['come',
#   'retreat',
#   'think',
#   'marriage',
#   'trouble',
#   'minute',
#   'thought',
#   'trouble',
#   'homer',
#   'expect',
#   'believe'],
#  ['marge',
#   'know',
#   'fish',
#   'mean',
#   'fish',
#   'represent',
#   'well',
#   'life',
#   'fish',
#   'make',
#   'champion',
#   'hero'],
#  ['weirdo', 'worm', 'store'],
#  ['fish', 'represent', 'selfish'],
#  ['way', 'feel', 'throw'],
#  ['oh', 'yeah', 'sure'],
#  ['wow',
#   'give',
#   'fame',
#   'breakfast',
#   'marriage',
#   'fight',
#   'hour',
#   'say',
#   'word',
#   'toss',
#   'tell',
#   'marriage',
#   'trouble',
#   'come',
#   'baby'],
#  ['oh', 'house', 'look', 'wonderful', 'grampa', 'secret'],
#  ['pretend',
#   'cry',
#   'right',
#   'hear',
#   'pretend',
#   'cry',
#   'turn',
#   'like',
#   'fawcet',
#   'boo',
#   'hoo',
#   'oh',
#   'cry',
#   'sad'],
#  ['trust', 'old', 'person'],
#  ['fool', 'long', 'sucker', 'hee', 'hee', 'hee'],
#  ['yup',
#   'general',
#   'sherman',
#   'pound',
#   'dwell',
#   'fury',
#   'know',
#   'know',
#   'old',
#   'ask',
#   'people',
#   'year',
#   'day'],
#  ['fella',
#   'come',
#   'close',
#   'go',
#   'homer',
#   'seven',
#   'foot',
#   'tall',
#   'arm',
#   'like',
#   'tree',
#   'trunk',
#   'eye',
#   'like',
#   'steel',
#   'cold',
#   'hard',
#   'shock',
#   'hair',
#   'red',
#   'like',
#   'fire',
#   'hell'],
#  ['hurry', 'mom', 'convention', 'soon', 'good', 'comic_strip', 'go'],
#  ['wow', 'number', 'fallout', 'boy', 'ward'],
#  ['care', 'good', 'comic_strip', 'buy', 'casper', 'wimpy', 'ghost'],
#  ['think',
#   'sad',
#   'equate',
#   'friendliness',
#   'wimpiness',
#   'hope',
#   'achieve',
#   'true',
#   'popularity'],
#  ['know', 'think', 'think', 'casper', 'ghost', 'richie', 'rich'],
#  ['hey', 'look', 'alike'],
#  ['wonder', 'richie', 'die'],
#  ['realize', 'hollow', 'pursuit', 'money', 'take', 'life'],
#  ['kid', 'lighten', 'little'],
#  ['radioactive', 'man', 'rule', 'punch', 'bad', 'guy', 'say', 'cool'],
#  ['oh', 'yeah', 'look', 'knock', 'guy', 'sun', 'say', 'hot', 'ya'],
#  ['bad', 'come', 'dressed', 'popular', 'cartoon', 'character'],
#  ['look', 'like', 'discount'],
#  ['uh',
#   'ahem',
#   'young',
#   'people',
#   'springfield',
#   'mayor',
#   'like',
#   'welcome',
#   'annual',
#   'funny',
#   'book',
#   'convention',
#   'thank',
#   'pump',
#   'dollar',
#   'local',
#   'economy'],
#  ['youthful',
#   'high',
#   'spirit',
#   'impart',
#   'glow',
#   'old',
#   'war',
#   'horse',
#   'feel',
#   'like',
#   'radiation',
#   'man'],
#  ['radioactive', 'man', 'jerk'],
#  ['stand',
#   'correct',
#   'fun',
#   'sure',
#   'clear',
#   'shriner',
#   'punk',
#   'make',
#   'fool',
#   'diamond',
#   'joe',
#   'quimby'],
#  ['excuse', 'sir', 'turn', 'left', 'vulcan', 'ear'],
#  ['let',
#   'get',
#   'utility',
#   'belt',
#   'couple',
#   'tricorder',
#   'light',
#   'saber',
#   'sorry',
#   'kid'],
#  ['hey', 'bart', 'dude'],
#  ['hey', 'otto', 'man', 'oooh'],
#  ['idea',
#   'comic',
#   'book',
#   'little',
#   'man',
#   'dude',
#   'drive',
#   'school',
#   'bus',
#   'day',
#   'night',
#   'fight',
#   'vampire',
#   'post',
#   'apocalyptic',
#   'warzone'],
#  ['come', 'bart', 'go', 'buddy', 'hodge'],
#  ['guy', 'play', 'fallout', 'boy', 'tv'],
#  ['wow', 'guess', 'kill', 'vietnam'],
#  ['aaahh',
#   'laramie',
#   'cigarette',
#   'steady',
#   'nerve',
#   'need',
#   'combat',
#   'evil'],
#  ['gee',
#   'whilliker',
#   'radioactive',
#   'man',
#   'wisht',
#   'old',
#   'smoke',
#   'laramie'],
#  ['sorry', 'fallout', 'boy', 'sixteen'],
#  ['radioactive', 'man', 'act', 'time', 'save', 'earth'],
#  ['great',
#   'know',
#   'kid',
#   'sure',
#   'like',
#   'remember',
#   'actor',
#   'dirk',
#   'richter',
#   'portrayal',
#   'radioactive',
#   'man',
#   'sordid',
#   'detail',
#   'final',
#   'year',
#   'let',
#   'question',
#   'tasteful',
#   'okay',
#   'big',
#   'welcome',
#   'buddy',
#   'fallout',
#   'boy',
#   'hodge'],
#  ['radioactive',
#   'man',
#   'get',
#   'inject',
#   'shrink',
#   'serum',
#   'issue',
#   'thirty',
#   'come',
#   'costume',
#   'shrink'],
#  ['sure',
#   'know',
#   'finish',
#   'play',
#   'rum',
#   'tum',
#   'tugger',
#   'second',
#   'national',
#   'touring',
#   'company',
#   'cat',
#   'anybody'],
#  ['ooh', 'ooh', 'ooh', 'ooh', 'fallout', 'boy', 'oh', 'oh'],
#  ['yes', 'mask', 'boy'],
#  ['think',
#   'ghost',
#   'dirk',
#   'richter',
#   'haunt',
#   'bordello',
#   'bullet',
#   'riddled',
#   'body',
#   'find'],
#  ['dirk', 'richter', 'beautiful', 'man', 'little', 'vulture', 'leave'],
#  ['hey',
#   'radioactive',
#   'man',
#   'number',
#   'seventy',
#   'imaginary',
#   'tale',
#   'radioactive',
#   'man',
#   'marry',
#   'larva',
#   'girl'],
#  ['tell', 'special', 'promise', 'grubby', 'little', 'hand', 'em'],
#  ['wow', 'radioactive', 'man', 'number'],
#  ['bet', 'worth', 'million', 'buck'],
#  ['lad', 'let', 'remind'],
#  ['moment', 'know', 'god', 'earth', 'know', 'buy', 'comic', 'book'],
#  ['emotion', 'place', 'son'],
#  ['yeah',
#   'mom',
#   'guess',
#   'dollar',
#   'man',
#   'sell',
#   'thirty',
#   'casper',
#   'dozen',
#   'lois',
#   'lane'],
#  ['know',
#   'superman',
#   'see',
#   'wonder',
#   'woman',
#   'golden',
#   'lariat',
#   'tie',
#   'time'],
#  ['kid', 'marge', 'hey', 'dinner', 'krusty', 'burger', 'treat'],
#  ['right',
#   'homer',
#   'whoa',
#   'sport',
#   'dad',
#   'take',
#   'fine',
#   'restaurant',
#   'like',
#   'krusty',
#   'burger'],
#  ['need', 'dollar', 'comic', 'book'],
#  ['buck', 'comic', 'book', 'draw', 'micha', 'ma', 'langelo'],
#  ['oh', 'dad', 'want', 'world'],
#  ['look',
#   'son',
#   'know',
#   'usually',
#   'bug',
#   'like',
#   'mad',
#   'try',
#   'show',
#   'pay',
#   'attention',
#   'know',
#   'going',
#   'to',
#   'dollar',
#   'going',
#   'to',
#   'stop',
#   'bug'],
#  ['hee', 'hee', 'win', 'face', 'yeah', 'like', 'apple', 'woo', 'hoo', 'hoo'],
#  ['gloat',
#   'homer',
#   'know',
#   'bart',
#   'age',
#   'thing',
#   'want',
#   'world',
#   'child',
#   'sized',
#   'electric',
#   'lightbulb',
#   'oven',
#   'parent',
#   'money',
#   'go',
#   'sister',
#   'patty',
#   'selma'],
#  ['uh', 'huh', 'slave'],
#  ['give', 'lot', 'free', 'time'],
#  ['uh', 'huh', 'let', 'smoke'],
#  ['month', 'work', 'work', 'sister', 'smoke', 'smoke'],
#  ['venu', 'oh', 'venus'],
#  ['want', 'dress', 'shield', 'hand', 'wash', 'drip', 'dry'],
#  ['big',
#   'day',
#   'finally',
#   'come',
#   'work',
#   'lightbulb',
#   'warm',
#   'treat',
#   'taste',
#   'extra',
#   'good'],
#  ['maybe', 'time', 'job', 'answer'],
#  ['aw', 'mom', 'ask', 'take', 'care', 'maggie', 'lisa', 'handful'],
#  ['mean', 'job', 'stupid'],
#  ['job',
#   'realize',
#   'time',
#   'little',
#   'piece',
#   'childhood',
#   'slip',
#   'away',
#   'forever'],
#  ['moment', 'dad', 'close'],
#  ['need', 'money', 'lot', 'money', 'ahh'],
#  ['ooh',
#   'good',
#   'like',
#   'deposit',
#   'defray',
#   'cost',
#   'jumbo',
#   'cherry',
#   'squishie'],
#  ['today', 'need', 'dime'],
#  ['oh', 'good', 'learn', 'trade'],
#  ['americanize', 'good', 'man'],
#  ['coin', 'worth', 'lousy', 'cent'],
#  ['let', 'good', 'time', 'roll'],
#  ['oh', 'humiliating', 'feel', 'like', 'geek'],
#  ['terrible', 'car', 'slow', 'laugh', 'buying'],
#  ['maybe', 'need', 'play', 'sympathy', 'let'],
#  ['ah', 'ha', 'look', 'pathetic'],
#  ['lemonade', 'suck', 'need', 'new', 'product', 'let', 'ah'],
#  ['form',
#   'line',
#   'crowd',
#   'cheap',
#   'beer',
#   'sympathetic',
#   'ear',
#   'step',
#   'right'],
#  ['ah', 'bart', 'credit', 'little', 'short', 'week'],
#  ['uh', 'get', 'liquor', 'license', 'young', 'fella'],
#  ['ugh', 'dog', 'eat'],
#  ['got', 'to', 'license', 'sell', 'beer'],
#  ['write', 'ticket', 'guy', 'thirsty', 'couple', 'house'],
#  ['ell', 'see', 'offense'],
#  ['long', 'officer', 'uh', 'oh'],
#  ['beer', 'beer', 'beautiful', 'beer'],
#  ['poor', 'boy', 'desperate', 'want', 'earn', 'money', 'buy', 'comic', 'book'],
#  ['comic', 'book', 'oh', 'boy', 'change', 'nazi', 'smasher'],
#  ['send', 'house', 'get', 'chore', 'know', 'mix', 'whitewash'],
#  ['eh', 'burt', 'simpson', 'look', 'like', 'get', 'strong', 'young'],
#  ['like',
#   'eat',
#   'get',
#   'dry',
#   'apricot',
#   'almond',
#   'paste',
#   'sauerkraut',
#   'candy'],
#  ['oh', 'brother', 'asa', 'kill', 'great', 'war', 'hold', 'grenade', 'long'],
#  ['kaiser',
#   'bill',
#   'special',
#   'delivery',
#   'uncle',
#   'sam',
#   'boy',
#   'company',
#   'yeah',
#   'johnny',
#   'harrison',
#   'brooklyn',
#   'bob',
#   'reggie',
#   'yeah',
#   'reggie',
#   'be',
#   'stick',
#   'know'],
#  ['ribbon', 'candy', 'boy', 'love', 'candy'],
#  ['boy', 'love', 'candy'],
#  ['oh', 'yes', 'ma', 'am'],
#  ['ugh', 'think', 'work', 'ma', 'am'],
#  ['start', 'little', 'light', 'yard', 'work', 'nice', 'barley', 'pop'],
#  ['want', 'clear', 'weed', 'know', 'one', 'weed'],
#  ['careful', 'inside', 'watch', 'story'],
#  ['filthy', 'genuinely', 'arouse'],
#  ['merciful', 'heaven', 'bleed', 'iodine'],
#  ['listen', 'lady', 'yaaauuuuggghhh'],
#  ['think', 'mrs', 'glick', 'nice', 'poor', 'old', 'thing', 'anybody'],
#  ['sludge', 'certainly', 'collect', 'downspout'],
#  ['sludge', 'old', 'bat'],
#  ['today', 'wash', 'beulah', 'know'],
#  ['old', 'lady', 'thing', 'hear', 'year'],
#  ['wedding', 'dress', 'dye', 'black', 'mourning', 'dress'],
#  ['great', 'story', 'lady'],
#  ['night', 'dream', 'hold', 'arm'],
#  ['iodine', 'burn', 'germ', 'torch', 'amputate', 'arm', 'yaaauuuggghhh'],
#  ['payday', 'wager', 'look', 'forward'],
#  ['deserve', 'penny', 'know', 'tell', 'lot', 'girlfriend', 'chore'],
#  ['listen',
#   'lady',
#   'leave',
#   'scream',
#   'leave',
#   'say',
#   'bad',
#   'word',
#   'way',
#   'say',
#   'thank'],
#  ['welcome', 'right', 'spend', 'penny', 'whistle', 'moon', 'pie'],
#  ['moon', 'pie', 'butt', 'somebody', 'oughta', 'moon', 'pie'],
#  ['bustin', 'hump', 'week', 'withered', 'old', 'clam', 'get', 'cent'],
#  ['hey', 'age', 'cent', 'lot', 'money'],
#  ['dad', 'get', 'thirty', 'buck', 'ugh', 'working', 'work', 'chump'],
#  ['son', 'proud', 'twice', 'age', 'figure'],
#  ['buck', 'forget', 'stool'],
#  ['get',
#   'sell',
#   'seed',
#   'visit',
#   'aunt',
#   'nursing',
#   'home',
#   'fish',
#   'dime',
#   'sewer',
#   'god',
#   'sake'],
#  ['freakin',
#   'kid',
#   'need',
#   'get',
#   'master',
#   'degree',
#   'folklore',
#   'mythology'],
#  ['excuse', 'carl', 'yastrzemski', 'baseball', 'card', 'big', 'sideburn'],
#  ['thirty', 'buck', 'be', 'get', 'be', 'gettin', 'stool'],
#  ['wait',
#   'minute',
#   'martin',
#   'milhouse',
#   'go',
#   'buy',
#   'copy',
#   'radioactive',
#   'man',
#   'right'],
#  ['freakin', 'kid'],
#  ['look', 'pal', 'get', 'buck', 'like', 'buy', 'radioactive', 'man', 'waddle'],
#  ['wow', 'breathe', 'boy'],
#  ['smell', 'like', 'grandpa'],
#  ['uh', 'oh', 'look', 'like', 'rain', 'well', 'baby', 'home'],
#  ['look', 'like', 'buy', 'bargain'],
#  ['pant', 'catch', 'barbed', 'wire', 'good', 'lord', 'choke', 'bomb'],
#  ['radioactive', 'day', 'forward', 'shall', 'radioactive', 'man'],
#  ['think', 'hit', 'atomic', 'bomb', 'kill'],
#  ['turn', 'page', 'bart'],
#  ['listen', 'guy', 'welcome', 'come', 'read', 'time', 'like'],
#  ['house', 'crazy', 'talk'],
#  ['guy',
#   'bart',
#   'monday',
#   'thursday',
#   'milhouse',
#   'tuesday',
#   'friday',
#   'truly',
#   'wednesday',
#   'saturday'],
#  ['wait', 'minute', 'sunday'],
#  ['sunday',
#   'possession',
#   'determine',
#   'random',
#   'number',
#   'generator',
#   'digit',
#   'milhouse',
#   'bart',
#   'seven'],
#  ['wait', 'minute', 'zero'],
#  ['unlikely',
#   'event',
#   'zero',
#   'possession',
#   'determine',
#   'rock',
#   'scissor',
#   'paper',
#   'competition',
#   'well'],
#  ['excellent', 'today', 'saturday', 'gentleman', 'guess', 'take', 'comic'],
#  ['uh',
#   'uh',
#   'uh',
#   'ah',
#   'nice',
#   'try',
#   'martin',
#   'work',
#   'tonight',
#   'comic',
#   'book',
#   'stay',
#   'right'],
#  ['comic', 'book', 'stay', 'right'],
#  ['fine',
#   'go',
#   'stay',
#   'comic',
#   'book',
#   'like',
#   'sleep',
#   'yeah',
#   'sleep',
#   'pal',
#   'right',
#   'real',
#   'friendly',
#   'like'],
#  ['nice', 'try', 'mister'],
#  ['milhouse',
#   'acid',
#   'hand',
#   'damage',
#   'newsprint',
#   'want',
#   'comic',
#   'forever',
#   'alive',
#   'honor',
#   'bury'],
#  ['know', 'make', 'sap', 'bartholemew', 'simpson'],
#  ['think', 'boy', 'like', 'milk', 'microwave', 'more'],
#  ['thank', 'mrs', 'simpson'],
#  ['sweet', 'dream', 'boy'],
#  ['step', 'dead', 'man'],
#  ['yeah', 'right', 'gettin'],
#  ['dear', 'friend', 'martin', 'try', 'steal', 'comic', 'book'],
#  ['bart', 'treat', 'guest'],
#  ['quiet', 'piggy', 'stick', 'apple', 'mouth', 'chance', 'turn', 'watch'],
#  ['oh',
#   'little',
#   'game',
#   'let',
#   'old',
#   'bart',
#   'nice',
#   'drowsy',
#   'turn',
#   'wham'],
#  ['go', 'crazy', 'bart', 'tell', 'mom'],
#  ['hey', 'martin', 'tell', 'squealer'],
#  ['know', 'bad', 'people', 'bathroom'],
#  ['homer', 'come', 'check', 'boy'],
#  ['milhouse', 'far', 'ground', 'rain', 'probably', 'soften', 'bit'],
#  ['know', 'guy', 'tie', 'save', 'comic', 'speak'],
#  ['help',
#   'bart',
#   'want',
#   'comic',
#   'want',
#   'carl',
#   'yastrzemski',
#   'big',
#   'burn'],
#  ['boy', 'well', 'come', 'house', 'want', 'sniffle'],
#  ['come',
#   'play',
#   'little',
#   'tie',
#   'game',
#   'inside',
#   'get',
#   'cocoa',
#   'stove',
#   'want',
#   'imitation',
#   'marshmallow'],
#  ['raise', 'hand', 'mrs', 'simpson'],
#  ['use', 'fellow', 'comic', 'book', 'return', 'earth', 'come'],
#  ['work', 'hard', 'go', 'end', 'share'],
#  ['world', 'safe', 'long'],
#  ['ah',
#   'chief',
#   'wiggum',
#   'archbishop',
#   'mcgee',
#   'distinguished',
#   'guest',
#   'pleased',
#   'dedicate',
#   'emergency',
#   'warning',
#   'system',
#   'uh',
#   'chance',
#   'nuclear',
#   'disaster',
#   'sign',
#   'tell',
#   'good',
#   'citizen',
#   'springfield'],
#  ['joke', 'core', 'explode', 'will', 'power', 'light', 'sign'],
#  ['like',
#   'present',
#   'man',
#   'sign',
#   'possible',
#   'drop',
#   'obstructionist',
#   'legal',
#   'challenge',
#   'montgomery',
#   'burn'],
#  ['mr', 'burns', 'late', 'terribly', 'wrong'],
#  ['well', 'leave', 'diamond', 'joe', 'quimby', 'hold', 'bag'],
#  ['turn', 'get', 'greet', 'dignitary'],
#  ['oh', 'mr', 'burn', 'get', 'doctor'],
#  ['absolutely',
#   'quack',
#   'sawbone',
#   'go',
#   'apply',
#   'leech',
#   'long',
#   'ounce',
#   'strength',
#   'leave'],
#  ['mmmm',
#   'mr',
#   'burns',
#   'suffer',
#   'medical',
#   'man',
#   'hypohemia',
#   'layman',
#   'term',
#   'simply',
#   'lack',
#   'blood'],
#  ['damn', 'doctor', 'idiot', 'know', 'hypohemia', 'want', 'know'],
#  ['point', 'hope', 'transfusion'],
#  ['long', 'sterilize', 'needle'],
#  ['afraid', 'simple', 'blood', 'type', 'double', 'negative', 'rare'],
#  ['positive', 'damn', 'common', 'gutter', 'blood', 'vein'],
#  ['smither', 'feel', 'bad', 'kidney', 'donate', 'hit', 'spot'],
#  ['hair', 'head', 'look'],
#  ['attention',
#   'employee',
#   'boss',
#   'inspiration',
#   'mr',
#   'burns',
#   'death',
#   'death',
#   'door',
#   'type',
#   'double',
#   'negative',
#   'blood',
#   'implore',
#   'report',
#   'bloodmobile',
#   'outside'],
#  ['believe',
#   'guy',
#   'human',
#   'million',
#   'dollar',
#   'need',
#   'help',
#   'wanna',
#   'cash',
#   'loser',
#   'stick',
#   'crummy',
#   'dead',
#   'end',
#   'job'],
#  ['know', 'homer', 'supervisor'],
#  ['lee', 'mur', 'lee', 'mur'],
#  ['zee', 'boo', 'zee', 'boo'],
#  ['try', 'teach', 'maggie', 'nature', 'end', 'barnyard', 'want', 'advantage'],
#  ['lisa', 'good', 'zebu'],
#  ['like', 'ox', 'hump', 'dewlap', 'hump', 'dew', 'lap', 'hump', 'dew', 'lap'],
#  ['marge', 'marge', 'blood', 'type'],
#  ['aw', 'nuts', 'extremely', 'rare', 'blood'],
#  ['know', 'blood', 'type', 'romantic'],
#  ['mother', 'know', 'family'],
#  ['oh', 'yeah', 'shoe', 'size'],
#  ['sixteen', 'permanent', 'baby'],
#  ['want', 'wear', 'ring', 'look', 'cheap'],
#  ['butterscotch', 'imitation', 'butterscotch'],
#  ['glow', 'dark', 'monster'],
#  ['oh', 'homie', 'lot', 'hair', 'want', 'know', 'blood', 'type'],
#  ['aw',
#   'old',
#   'man',
#   'burn',
#   'going',
#   'to',
#   'kick',
#   'double',
#   'negative',
#   'blood',
#   'plant'],
#  ['woo',
#   'you',
#   'right',
#   'woo',
#   'congratulation',
#   'boy',
#   'get',
#   'date',
#   'needle'],
#  ['hey', 'wait', 'minute', 'blood', 'right', 'know'],
#  ['yeah', 'right', 'remain', 'silent'],
#  ['bart', 'help', 'need', 'decent', 'thing'],
#  ['bart',
#   'like',
#   'ask',
#   'blood',
#   'free',
#   'crazy',
#   'little',
#   'young',
#   'understand',
#   'save',
#   'rich',
#   'man',
#   'life',
#   'shower',
#   'rich',
#   'know',
#   'story',
#   'hercule',
#   'lion'],
#  ['yeah',
#   'probably',
#   'time',
#   'big',
#   'mean',
#   'lion',
#   'get',
#   'thorn',
#   'paw',
#   'village',
#   'people',
#   'try',
#   'pull',
#   'strong',
#   'get',
#   'hercule',
#   'hercule',
#   'mighty',
#   'strength',
#   'bingo',
#   'moral',
#   'lion',
#   'happy',
#   'give',
#   'hercule',
#   'big',
#   'thing',
#   'rich'],
#  ['hey', 'let', 'emergency', 'life', 'death'],
#  ['whoa', 'otto', 'man', 'work'],
#  ['oh',
#   'yeah',
#   'you',
#   'friend',
#   'school',
#   'get',
#   'job',
#   'certified',
#   'bloodlette',
#   'tech',
#   'dude'],
#  ['okay', 'let', 'wash'],
#  ['homer', 'brave', 'young', 'bart', 'know', 'hug'],
#  ['smither', 'go', 'want', 'dictate', 'epitaph'],
#  ['charles', 'montgomery', 'burn'],
#  ['american', 'patriot'],
#  ['tyrant', 'hear', 'mighty', 'quake', 'smither'],
#  ['oh', 'mornin', 'ye', 'look', 'good', 'old'],
#  ['hi', 'mr', 'burn'],
#  ['oh', 'hey', 'mr', 'brown', 'shoe', 'local', 'sport', 'team', 'hm'],
#  ['mr', 'burn', 'okay', 'jackpot'],
#  ['heh', 'heh', 'heh', 'game', 'hasta', 'manana', 'osvaldo'],
#  ['smither', 'pink', 'pith', 'vinegar'],
#  ['know',
#   'funny',
#   'smither',
#   'try',
#   'tincture',
#   'poultice',
#   'tonic',
#   'patent',
#   'medicine',
#   'need',
#   'blood',
#   'young',
#   'boy',
#   'way',
#   'lad'],
#  ['uh', 'bart', 'simpson', 'sir'],
#  ['son', 'homer', 'simpson', 'stiff', 'sector'],
#  ['simpson', 'get', 'nice', 'surprise', 'mail', 'nice'],
#  ['bill',
#   'bill',
#   'summons',
#   'bill',
#   'wait',
#   'minute',
#   'burns',
#   'yes',
#   'woo',
#   'hoo',
#   'woo'],
#  ['marge', 'lisa', 'maggie', 'let', 'yard', 'neighbor'],
#  ['lisa', 'dim', 'light', 'turn', 'light'],
#  ['little', 'thin', 'okay', 'check'],
#  ['well', 'half', 'marge', 'well', 'half'],
#  ['right',
#   'check',
#   'card',
#   'panic',
#   'sure',
#   'tell',
#   'get',
#   'pick',
#   'dear',
#   'bart',
#   'thank',
#   'kindly',
#   'blood',
#   'truly',
#   'montgomery',
#   'burn',
#   'card'],
#  ['way',
#   'gratitude',
#   'gold',
#   'diamond',
#   'ruby',
#   'lousy',
#   'card',
#   'wait',
#   'minute',
#   'card',
#   'get',
#   'mad',
#   'place'],
#  ['homer',
#   'thing',
#   'like',
#   'reward',
#   'fellow',
#   'human',
#   'need',
#   'help',
#   'hand'],
#  ['marge',
#   'wife',
#   'love',
#   'live',
#   'world',
#   'believe',
#   'flower',
#   'bell',
#   'leprechaun',
#   'magic',
#   'frog',
#   'funny',
#   'little',
#   'hat'],
#  ['yeah', 'mom', 'get', 'hose'],
#  ['get', 'exactly', 'want', 'give', 'old', 'man', 'second', 'chance'],
#  ['promise',
#   'boy',
#   'simple',
#   'thing',
#   'lot',
#   'rich',
#   'man',
#   'break',
#   'promise',
#   'bart',
#   'letter'],
#  ['dear',
#   'mr',
#   'burns',
#   'glaaad',
#   'enjoy',
#   'son',
#   'blood',
#   'caard',
#   'great',
#   'case',
#   'tell',
#   'sarcastic',
#   'stink',
#   'read'],
#  ['good',
#   'senile',
#   'buck',
#   'toothe',
#   'old',
#   'mummy',
#   'bony',
#   'girl',
#   'arm',
#   'smell',
#   'like'],
#  ['boss', 'mail', 'right', 'minute'],
#  ['angry', 'homer', 'sleep'],
#  ['oh', 'right', 'hand', 'thing', 'usually', 'work'],
#  ['homer', 'breakfast', 'ready'],
#  ['oh',
#   'marge',
#   'save',
#   'make',
#   'big',
#   'mistake',
#   'know',
#   'finally',
#   'understand',
#   'meaning',
#   'mmphm',
#   'hnmph'],
#  ['homer', 'think', 'cornstarch', 'canister'],
#  ['bart', 'see', 'letter'],
#  ['right', 'think', 'carefully'],
#  ['shove', 'mailbox'],
#  ['dad',
#   'thing',
#   'letter',
#   'say',
#   'know',
#   'emotional',
#   'guy',
#   'mad',
#   'night',
#   'guarantee',
#   'mad',
#   'morning'],
#  ['homer', 'encourage', 'strangle'],
#  ['right',
#   'okay',
#   'think',
#   'homer',
#   'panic',
#   'pick',
#   'mail',
#   'till',
#   'noon',
#   'time'],
#  ['ow', 'ow', 'ow', 'ow', 'ow', 'ow', 'ow'],
#  ['homer', 'lock', 'tight'],
#  ['lock',
#   'eh',
#   'little',
#   'surprise',
#   'sleeve',
#   'old',
#   'mr',
#   'lock',
#   'step',
#   'aside',
#   'boy'],
#  ['hey', 'homer', 'fight', 'power'],
#  ['look', 'like', 'letter', 'wet', 'ink', 'run', 'able', 'read'],
#  ['yeah', 'people', 'mail'],
#  ['people',
#   'will',
#   'letter',
#   'boo',
#   'hoo',
#   'know',
#   'kinda',
#   'letter',
#   'people',
#   'write',
#   'dear',
#   'somebody',
#   'hear',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'truly',
#   'bozo',
#   'big',
#   'loss'],
#  ['bart', 'eye', 'mailman', 'kind', 'signal'],
#  ['dear', 'god', 'plan', 'water', 'mail'],
#  ['uh',
#   'uh',
#   'guess',
#   'good',
#   'run',
#   'cause',
#   'mail',
#   'lady',
#   'know',
#   'address',
#   'huh'],
#  ['going', 'to', 'run'],
#  ['want', 'world', 'hear', 'story', 'harrowing', 'struggle', 'hypohemia'],
#  ['sir', 'mr', 'roman', 'fine', 'ghostwriter', 'business'],
#  ['write', 'like', 'hell', 'muck', 'unsinkable', 'sadruddin', 'mahbaradad'],
#  ['right', 'right', 'question', 'sleep', 'famous'],
#  ['countess',
#   'van',
#   'zeplin',
#   'blaze',
#   'listen',
#   'bargain',
#   'basement',
#   'baudelaire',
#   'dizzy',
#   'starlet',
#   'stre',
#   'word',
#   'write',
#   'thing',
#   'fire'],
#  ['okay', 'mr', 'burn'],
#  ['great', 'plan', 'bart'],
#  ['ooh', 'look', 'maggie', 'dec', 'ah', 'edron', 'dodecahedron'],
#  ['lisa', 'know', 'strange', 'father', 'try', 'worry'],
#  ['chapter', 'fifth', 'trip', 'infirmary', 'unexpected', 'result'],
#  ['minute', 'till', 'burn', 'come', 'time', 'operation', 'mail'],
#  ['tell', 'going', 'to', 'destroy', 'family', 'believe'],
#  ['oh', 'frighten', 'letter', 'opener'],
#  ['hello', 'case', 'tell', 'sarcastic'],
#  ['stink',
#   'senile',
#   'buck',
#   'toothe',
#   'old',
#   'mummy',
#   'bony',
#   'girl',
#   'arm',
#   'smell',
#   'like',
#   'elephant',
#   'butt'],
#  ['hey', 'come', 'joey', 'twist', 'arm'],
#  ['homer', 'tell', 'job', 'okay'],
#  ['crush',
#   'like',
#   'ant',
#   'easy',
#   'revenge',
#   'dish',
#   'well',
#   'serve',
#   'cold',
#   'bide',
#   'time',
#   'oh',
#   'hell',
#   'crush',
#   'like',
#   'ant'],
#  ['senile',
#   'eh',
#   'buck',
#   'toothe',
#   'bony',
#   'arm',
#   'liver',
#   'spot',
#   'chinless'],
#  ['pink', 'slip', 'await', 'signature', 'sir'],
#  ['odd',
#   'rob',
#   'man',
#   'livelihood',
#   'feel',
#   'strangely',
#   'tell',
#   'smither',
#   'beat',
#   'pulp'],
#  ['oh', 'see', 'mr', 'burn', 'mad', 'kinda', 'mad'],
#  ['big', 'letter', 'write', 'pen'],
#  ['honey', 'matter', 'happen', 'pull'],
#  ['okay',
#   'plan',
#   'sister',
#   'raise',
#   'kid',
#   'die',
#   'gutter',
#   'practical',
#   'mean'],
#  ['okay', 'bart', 'believe', 'try', 'scare'],
#  ['know', 'homer', 'simpson'],
#  ['yeah', 'nice', 'guy', 'play', 'poker'],
#  ['hmmm', 'huh', 'uh', 'need', 'beat'],
#  ['hold', 'kick', 'get'],
#  ['uh', 'um', 'umm'],
#  ['save', 'mr', 'burn', 'life'],
#  ['close',
#   'gentle',
#   'reader',
#   'like',
#   'thank',
#   'thank',
#   'misprint',
#   'enjoy',
#   'write',
#   'book',
#   'enjoy',
#   'read',
#   'end'],
#  ['ah', 'smither', 'beating'],
#  ['sir', 'uh', 'beating'],
#  ['sorry', 'sir', 'hurt', 'homer', 'simpson', 'save', 'life'],
#  ['know',
#   'mad',
#   'think',
#   'fair',
#   'warn',
#   'go',
#   'stand',
#   'outside',
#   'gate',
#   'forgive'],
#  ['need',
#   'smither',
#   'usual',
#   'sober',
#   'ying',
#   'rage',
#   'yang',
#   'er',
#   'old',
#   'pal'],
#  ['sir', 'wish', 'handshake', 'end', 'afraid', 'simpson', 'matter', 'attend'],
#  ['moe', 'tavern', 'elite', 'meet', 'drink'],
#  ['eh', 'yeah', 'hello', 'mike', 'rotch'],
#  ['hold',
#   'check',
#   'mike',
#   'rotch',
#   'mike',
#   'rotch',
#   'hey',
#   'anybody',
#   'see',
#   'mike',
#   'rotch',
#   'lately'],
#  ['listen',
#   'little',
#   'puke',
#   'day',
#   'going',
#   'to',
#   'catch',
#   'going',
#   'to',
#   'carve',
#   'ice',
#   'pick'],
#  ['matter', 'homer', 'normal', 'effervescent', 'self'],
#  ['get', 'problem', 'moe'],
#  ['homer', 'hey', 'drink', 'forget', 'problem'],
#  ['yeah', 'drink', 'enhance', 'social', 'skill'],
#  ['simpson',
#   'present',
#   'extravagant',
#   'present',
#   'mad',
#   'unthinkable',
#   'utterly',
#   'impossible',
#   'present',
#   'frabulous',
#   'grabulous',
#   'zip',
#   'zoop',
#   'zabulous',
#   'present'],
#  ['pool', 'table', 'mad', 'going', 'to', 'turn', 'home', 'saloon'],
#  ['sir', 'thirty', 'thousand', 'dollar'],
#  ['dare', 'sully', 'moment', 'price', 'taggery', 'perfect'],
#  ['oh', 'mr', 'burns'],
#  ['heave', 'ho', 'heave', 'ho', 'heave', 'ho', 'heave', 'ho', 'heave', 'ho'],
#  ['wait', 'dad', 'smile'],
#  ['mr', 'burn', 'bring', 'present'],
#  ['think', 'go', 'beat', 'bloody', 'pulp'],
#  ['hard',
#   'feeling',
#   'advance',
#   'copy',
#   'book',
#   'rainbow',
#   'young',
#   'fellow',
#   'forget'],
#  ['open', 'crate', 'stupid'],
#  ['tell', 'bet', 'fill', 'diamond', 'ruby', 'sapphire', 'pearl'],
#  ['wow', 'big', 'ugly', 'head'],
#  ['actually',
#   'son',
#   'big',
#   'ugly',
#   'olmec',
#   'indian',
#   'head',
#   'carve',
#   'meso',
#   'american',
#   'indians',
#   'year',
#   'ago',
#   'gruesome',
#   'customer',
#   'xt',
#   'tapalatakettle',
#   'god',
#   'war'],
#  ['maggie', 'az', 'tec', 'ol', 'mec', 'ol', 'mec'],
#  ['let', 'acquaint', 'se', 'xt', 'tapalatakettle', 'ta'],
#  ['sir', 'god', 'generosity'],
#  ['save',
#   'guy',
#   'life',
#   'whattaya',
#   'nothing',
#   'bad',
#   'nothing',
#   'big',
#   'scary',
#   'rock'],
#  ['hey', 'man', 'bad', 'mouth', 'head'],
#  ['homer', 'thought', 'count', 'moral', 'story', 'good', 'deed', 'reward'],
#  ['hey', 'get', 'reward', 'head', 'cool'],
#  ['guess', 'moral', 'good', 'deed', 'go', 'unrewarded'],
#  ['wait', 'minute', 'write', 'nasty', 'letter', 'get'],
#  ['guess', 'moral', 'squeaky', 'wheel', 'get', 'grease'],
#  ['exactly', 'bunch', 'stuff', 'happen'],
#  ['certainly', 'memorable', 'day'],
#  ['bart', 'bart', 'hey', 'bart'],
#  ['lisa', 'wrong', 'dad', 'die'],
#  ['bart',
#   'birthday',
#   'day',
#   'going',
#   'to',
#   'year',
#   'old',
#   'big',
#   'number',
#   'double',
#   'digit'],
#  ['enjoy',
#   'change',
#   'hit',
#   'big',
#   'oh',
#   'leg',
#   'start',
#   'candy',
#   'taste',
#   'good',
#   'anymore'],
#  ['bart', 'let', 'pour', 'little', 'heart'],
#  ['sorry', 'old', 'timer', 'ramble'],
#  ['bart',
#   'disappoint',
#   'birthday',
#   'thing',
#   'lose',
#   'break',
#   'hour',
#   'okay',
#   'forget'],
#  ['okay',
#   'uh',
#   'huh',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'okay',
#   'birthday',
#   'gift',
#   'come',
#   'way'],
#  ['bart', 'watch', 'maggie', 'laundry'],
#  ['hm', 'krusty', 'hotline'],
#  ['hi',
#   'kid',
#   'reach',
#   'krusty',
#   'hotline',
#   'ask',
#   'parent',
#   'permission',
#   'naughty',
#   'naughty',
#   'krusty',
#   'forgive',
#   'dollar',
#   'minute',
#   'cent',
#   'additional',
#   'minute'],
#  ['thank', 'call', 'kid', 'new', 'message', 'day'],
#  ['bart', 'ask', 'watch', 'sister'],
#  ['try', 'stop', 'overpower'],
#  ['steal', 'shirt', 'steal', 'shirt'],
#  ['oh', 'thank', 'marge', 'pink'],
#  ['marge',
#   'wear',
#   'pink',
#   'shirt',
#   'work',
#   'everybody',
#   'wear',
#   'white',
#   'shirt',
#   'popular',
#   'different'],
#  ['homer', 'panic', 'plenty', 'white', 'shirt'],
#  ['oh', 'gimme', 'gimme', 'gimme', 'gimme', 'gimme'],
#  ['oh', 'pink', 'pink', 'pink', 'marge'],
#  ['ah', 'lucky', 'red', 'hat', 'clean', 'whistle'],
#  ['homer', 'go', 'notice', 'wear', 'pink', 'shirt', 'work'],
#  ['wait', 'minute', 'zoom', 'man', 'pink'],
#  ['oh', 'homer', 'simpson', 'sir', 'boob', 'sector'],
#  ['simpson',
#   'eh',
#   'judge',
#   'outlandish',
#   'attire',
#   'sort',
#   'free',
#   'thinking',
#   'anarchist'],
#  ['excellent', 'color', 'monitor', 'pay'],
#  ['hey', 'homer', 'save', 'doughnut'],
#  ['mmm',
#   'thank',
#   'look',
#   'hey',
#   'wait',
#   'minute',
#   'wear',
#   'pink',
#   'shirt',
#   'mean',
#   'kind',
#   'pink',
#   'doughnut',
#   'eater',
#   'tempt'],
#  ['understand', 'son', 'throw', 'red', 'hat', 'white', 'laundry'],
#  ['spare', 'tired', 'semantic', 'simpson', 'family', 'away'],
#  ['know',
#   'mr',
#   'burn',
#   'body',
#   'cavity',
#   'search',
#   'reveal',
#   'ray',
#   'time',
#   'maybe',
#   'tell',
#   'truth'],
#  ['cahoots', 'smither', 'recall', 'penchant', 'bell', 'trouser'],
#  ['uh', 'sir', 'costume', 'plant', 'production', 'pinafore'],
#  ['oh',
#   'yes',
#   'course',
#   'spirited',
#   'hornpipe',
#   'steal',
#   'recall',
#   'doctor',
#   'shall',
#   'free',
#   'wheeling',
#   'fop'],
#  ['monty',
#   'establish',
#   'patient',
#   'sanity',
#   'take',
#   'month',
#   'change',
#   'thank',
#   'marvin',
#   'monroe',
#   'home',
#   'personality',
#   'test',
#   'simple',
#   'question',
#   'determine',
#   'crazy',
#   'meshuggenah'],
#  ['honey', 'favor', 'fill', 'form'],
#  ['homer', 'intimate', 'psychological', 'profile', 'fill'],
#  ['right', 'right', 'lisa'],
#  ['lisa', 'like', 'homework', 'fill', 'form'],
#  ['right', 'listen', 'poem', 'write'],
#  ['meditation',
#   'turn',
#   'lisa',
#   'simpson',
#   'cat',
#   'name',
#   'snowball',
#   'die',
#   'die',
#   'mom',
#   'say',
#   'sleep',
#   'lie',
#   'lie',
#   'oh',
#   'cat',
#   'dead',
#   'chrysler',
#   'hit',
#   'instead',
#   'hamster',
#   'name',
#   'snuffy',
#   'die'],
#  ['son', 'different', 'time', 'let', 'vote', 'remember', 'absentee', 'ballot'],
#  ['home', 'video', 'finalist', 'man', 'break', 'hip'],
#  ['dog', 'fire', 'ruff', 'anybody', 'order', 'hot', 'dog'],
#  ['finally', 'baby', 'nail', 'gun'],
#  ['okay', 'time', 'cast', 'vote'],
#  ['dog', 'fire', 'dog', 'fire'],
#  ['hey', 'dad', 'hear', 'voice'],
#  ['yes', 'hear', 'right', 'try', 'watch', 'tv'],
#  ['yes', 'quick', 'anger'],
#  ['bart', 'shut', 'shut'],
#  ['yes', 'wet', 'pant', 'good', 'occasional', 'accident'],
#  ['careful', 'man', 'wet', 'pant'],
#  ['devil', 'fly', 'open'],
#  ['spill', 'floor', 'bug', 'going', 'going', 'to', 'eat'],
#  ['happy', 'birthday', 'lisa'],
#  ['boy', 'fair', 'tell', 'sane', 'insane'],
#  ['stamp', 'hand', 'insane'],
#  ['big', 'white', 'guy', 'think', 'little', 'black', 'guy'],
#  ['hi', 'michael', 'jackson', 'jackson'],
#  ['homer', 'simpson', 'simpson'],
#  ['believe', 'hear', 'popular', 'entertainer'],
#  ['oh', 'course', 'hear', 'mean', 'live', 'rock', 'know'],
#  ['billie', 'jean', 'lover', 'girl', 'say', 'kid', 'son', 'hee', 'hee', 'hee'],
#  ['wow', 'thing', 'foot'],
#  ['look', 'raise', 'heel', 'bit', 'little', 'pressure', 'ball', 'foot'],
#  ['hee', 'hee', 'hee'],
#  ['like', 'nice', 'guy'],
#  ['wear', 'pink', 'shirt'],
#  ['understand', 'people', 'think', 'crazy', 'way', 'dress'],
#  ['white', 'glove', 'cover', 'rhinestone'],
#  ['bbl', 'bbl', 'bbl', 'bbl'],
#  ['bart',
#   'split',
#   'second',
#   'die',
#   'bet',
#   'scratchy',
#   'appreciate',
#   'birthday',
#   'present',
#   'relate'],
#  ['hey', 'want', 'year', 'gesture', 'get', 'sis'],
#  ['hey', 'michael', 'guy', 'normal'],
#  ['homer', 'floyd', 'idiot', 'savant', 'number', 'multiply', 'head', 'like'],
#  ['guy', 'chief', 'say', 'word', 'move', 'muscle'],
#  ['time', 'somebody', 'reach'],
#  ['gee', 'got', 'to', 'family'],
#  ['oh', 'embarrassing', 'call', 'em', 'nut', 'house', 'mean', 'think', 'god'],
#  ['oh',
#   'great',
#   'uh',
#   'try',
#   'good',
#   'face',
#   'tell',
#   'place',
#   'rich',
#   'woman',
#   'lose',
#   'weight'],
#  ['joe', 'crematorium', 'kill', 'em', 'grill', 'em'],
#  ['bart', 'simpson', 'hell'],
#  ['michael', 'jackson', 'way'],
#  ['true', 'father', 'mental', 'institution'],
#  ['uh', 'huh', 'elvis'],
#  ['aw', 'come', 'michael', 'jackson', 'date', 'grammys'],
#  ['brooke', 'shield', 'diana', 'ross', 'emmanuel', 'lewis', 'bubble'],
#  ['shiver',
#   'timber',
#   'michael',
#   'jackson',
#   'stay',
#   'line',
#   'friend',
#   'relative'],
#  ['afraid', 'bart', 'father', 'need', 'help', 'want', 'lobotomy'],
#  ['probably',
#   'size',
#   'uh',
#   'huh',
#   'new',
#   'bedlam',
#   'asylum',
#   'love',
#   'need',
#   'fear',
#   'get',
#   'michael',
#   'jackson',
#   'whoo',
#   'hoo',
#   'love',
#   'man'],
#  ['hey', 'mom', 'dad', 'mental', 'institution'],
#  ['oh', 'god', 'mother', 'right'],
#  ['homer', 'worry', 'family', 'going', 'to', 'know'],
#  ['forget', 'pal', 'way', 'be', 'pretty'],
#  ['tell', 'kid', 'go', 'send', 'father', 'crazy', 'house'],
#  ['mom', 'say', 'poor', 'house'],
#  ['say', 'crazy', 'house'],
#  ['hello',
#   'reach',
#   'new',
#   'bedlam',
#   'wrongly',
#   'commit',
#   'hotline',
#   'operator',
#   'currently',
#   'busy',
#   'stay',
#   'line'],
#  ['place', 'strange', 'mike', 'ashamed', 'admit', 'guy', 'scared'],
#  ['scared', 'maybe', 'help'],
#  ['homer',
#   'need',
#   'look',
#   'find',
#   'look',
#   'friend',
#   'friend',
#   'get',
#   'friend'],
#  ['pancakes', 'football', 'booby'],
#  ['bubble', 'going', 'to', 'long', 'night'],
#  ['wish', 'love', 'good', 'wish', 'peace', 'joy'],
#  ['feel',
#   'free',
#   'express',
#   'session',
#   'want',
#   'feel',
#   'relaxed',
#   'uninhibite'],
#  ['okay',
#   'work',
#   'insurance',
#   'company',
#   'right',
#   'huh',
#   'young',
#   'vp',
#   'history',
#   'firm',
#   'okay',
#   'job',
#   'life',
#   'monday',
#   'morning',
#   'get',
#   'leave',
#   'house'],
#  ['homer',
#   'dave',
#   'suffer',
#   'agoraphobia',
#   'fear',
#   'open',
#   'area',
#   'crowd',
#   'dave'],
#  ['thank', 'day', 'know', 'long', 'drive', 'work'],
#  ['mrs',
#   'simpson',
#   'sorry',
#   'husband',
#   'suffer',
#   'persecution',
#   'complex',
#   'extreme',
#   'paranoia',
#   'bladder',
#   'hostility'],
#  ['doctor', 'talk', 'minute', 'mention', 'son', 'bart', 'sane'],
#  ['mean', 'bart', 'good', 'lord'],
#  ['oh', 'mr', 'simpson', 'get', 'visitor'],
#  ['mr', 'simpson', 'talk', 'wife', 'believe', 'threat'],
#  ['flattering', 'thing', 'say', 'write'],
#  ['thank', 'lot', 'michael', 'help', 'find', 'marble', 'come', 'visit'],
#  ['get',
#   'real',
#   'depressed',
#   'wall',
#   'album',
#   'get',
#   'lousy',
#   'grammy',
#   'nomination'],
#  ['happy',
#   'birthday',
#   'happy',
#   'birthday',
#   'happy',
#   'birthday',
#   'overlook',
#   'middle',
#   'child',
#   'happy',
#   'birthday'],
#  ['joe', 'taxidermy', 'snuff', 'em', 'stuff', 'em'],
#  ['boy', 'home', 'go', 'wrap', 'hand', 'neck'],
#  ['homer', 'get', 'cut', 'dose'],
#  ['listen',
#   'bring',
#   'michael',
#   'jackson',
#   'home',
#   'stay',
#   'day',
#   'cute',
#   'hear',
#   'sure',
#   'plenty',
#   'cold',
#   'cut',
#   'beer',
#   'ice'],
#  ['um', 'homer', 'vegetarian', 'drink'],
#  ['yes', 'homer', 'sure', 'tell', 'anybody', 'come'],
#  ['yes', 'dad', 'solemnly', 'swear', 'tell', 'live', 'soul', 'milhouse'],
#  ['hello', 'milhouse', 'secret'],
#  ['oh', 'care', 'michael', 'jackson', 'come', 'house'],
#  ['aunt', 'bella', 'wait', 'minute', 'get', 'line', 'michael', 'jackson'],
#  ['hand', 'bulletin', 'rock', 'rumor', 'department'],
#  ['right',
#   'michael',
#   'jackson',
#   'thriller',
#   'moonwalkin',
#   'way',
#   'right',
#   'spring',
#   'field'],
#  ['check',
#   'enjoy',
#   'seldom',
#   'hear',
#   'extra',
#   'longggg',
#   'version',
#   'gadda',
#   'da',
#   'vida'],
#  ['michael',
#   'jackson',
#   'oh',
#   'thing',
#   'happen',
#   'blue',
#   'moon',
#   'dare',
#   'leave',
#   'post'],
#  ['exciting',
#   'thing',
#   'happen',
#   'fair',
#   'town',
#   'uh',
#   'dalai',
#   'lama',
#   'visit',
#   'declare',
#   'route',
#   'currently',
#   'know',
#   'dalai',
#   'lama',
#   'expressway',
#   'henceforth',
#   'know',
#   'michael',
#   'jackson',
#   'expressway'],
#  ['guy',
#   'pink',
#   'shirt',
#   'father',
#   'family',
#   'turn',
#   'release',
#   'mental',
#   'hospital'],
#  ['thank', 'everybody', 'great', 'sane'],
#  ['hell', 'think', 'michael', 'jackson', 'visit', 'jerkwater', 'burg'],
#  ['owe', 'michael', 'jackson'],
#  ['face', 'ya', 'tool'],
#  ['bart',
#   'entire',
#   'town',
#   'howl',
#   'blood',
#   'join',
#   'question',
#   'today',
#   'birthday',
#   'promise',
#   'afraid',
#   'ask'],
#  ['know', 'maybe', 'trust', 'instinct', 'ask'],
#  ['think', 'oh', 'bart'],
#  ['dear',
#   'bart',
#   'stationery',
#   'mom',
#   'dad',
#   'give',
#   'birthday',
#   'inform',
#   'brother',
#   'sister',
#   'professional',
#   'advise',
#   'hug',
#   'far',
#   'distant',
#   'family',
#   'reunion',
#   'rest',
#   'assure',
#   'purely'],
#  ['wish', 'well', 'heart', 'desire'],
#  ['bart', 'kid', 'money', 'know', 'sister', 'birthday', 'roll'],
#  ['write', 'song', 'care'],
#  ['age', 'gold', 'record'],
#  ['hey',
#   'looney',
#   'tune',
#   'michael',
#   'jackson',
#   'look',
#   'like',
#   'look',
#   'like',
#   'big',
#   'fat',
#   'mental',
#   'patient'],
#  ['look',
#   'boy',
#   'michael',
#   'jackson',
#   'guy',
#   'work',
#   'recording',
#   'studio',
# ...
#   'electorate',
#   'baste',
#   'veto',
#   'power'],
#  ['spineless', 'belly', 'yellow', 'american', 'non', 'voter'],
#  ['stir', 'cup', 'check', 'sprinkle', 'liberally', 'balance'],
#  ['ding',
#   'dong',
#   'sound',
#   'liberty',
#   'bell',
#   'ding',
#   'freedom',
#   'dong',
#   'opportunity',
#   'ding',
#   'excellent',
#   'school',
#   'dong',
#   'quality',
#   'hospital'],
#  ['america',
#   'bear',
#   'hot',
#   'july',
#   'day',
#   'tree',
#   'springfield',
#   'forest',
#   'tiny',
#   'sapling',
#   'tremble',
#   'sun',
#   'nourish',
#   'mother',
#   'earth',
#   'fledgling',
#   'nation',
#   'find',
#   'strength',
#   'simple',
#   'ideal',
#   'equality',
#   'justice',
#   'think',
#   'mighty',
#   'oak',
#   'powerful',
#   'nation',
#   'grow',
#   'fragile',
#   'pure',
#   'thank'],
#  ['good',
#   'little',
#   'good',
#   'year',
#   'old',
#   'methink',
#   'detect',
#   'sickly',
#   'scent',
#   'daddy'],
#  ['mr',
#   'simpson',
#   'like',
#   'ask',
#   'question',
#   'daughter',
#   'essay',
#   'lisa',
#   'excuse'],
#  ['interested', 'politic', 'government'],
#  ['lisa',
#   'meet',
#   'father',
#   'decide',
#   'award',
#   'additional',
#   'point',
#   'congratulation',
#   'family',
#   'go',
#   'washington'],
#  ['woo', 'hoo', 'guess', 'reading', 'writing', 'pay'],
#  ['play',
#   'card',
#   'notepad',
#   'aspirin',
#   'sewing',
#   'kit',
#   'pilot',
#   'wing',
#   'pin',
#   'propellor',
#   'shape',
#   'swizzle',
#   'stick',
#   'sleep',
#   'mask',
#   'get',
#   'come'],
#  ['little', 'boy', 'bet', 'like', 'visit', 'cockpit'],
#  ['control', 'stick', 'like', 'handlebar', 'tricycle', 'like', 'hang', 'coat'],
#  ['thank', 'push', 'button'],
#  ['going', 'to', 'die'],
#  ['look', 'marge', 'guy', 'taxi'],
#  ['oooh', 'look', 'homer', 'irs'],
#  ['homer',
#   'look',
#   'shower',
#   'cap',
#   'body',
#   'gel',
#   'bathrobe',
#   'ooh',
#   'welcome',
#   'mint',
#   'pillow'],
#  ['wowww', 'shoehorn', 'like', 'movie'],
#  ['shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go',
#   'shoe',
#   'go'],
#  ['bart', 'thing', 'bedsie'],
#  ['good', 'night', 'sleep', 'lisa'],
#  ['stupid', 'welcoming', 'mint', 'ello'],
#  ['good', 'morning', 'wake'],
#  ['lisa', 'faith', 'crowley', 'patriotism', 'editor', 'read', 'digest'],
#  ['ooh',
#   'love',
#   'magazine',
#   'favorite',
#   'section',
#   'increase',
#   'word',
#   'power',
#   'thing',
#   'good'],
#  ['lisa',
#   'like',
#   'meet',
#   'finalist',
#   'truong',
#   'van',
#   'dinh',
#   'maria',
#   'dominguez'],
#  ['maria',
#   'national',
#   'spelling',
#   'bee',
#   'champion',
#   'truong',
#   'win',
#   'westinghouse',
#   'talent',
#   'search',
#   'nfl',
#   'punt',
#   'pass',
#   'kick',
#   'competition'],
#  ['run', 'problem', 'superior', 'ability'],
#  ['special', 'vip', 'badge', 'place', 'tourist'],
#  ['spot', 'richard', 'nixon', 'bowl', 'game'],
#  ['wow', 'president', 'bathroom'],
#  ['oh', 'damn', 'badge', 'okay', 'tub', 'instal'],
#  ['hey', 'watch', 'chief'],
#  ['folk',
#   'print',
#   'eighteen',
#   'million',
#   'bill',
#   'day',
#   'oh',
#   'case',
#   'wonder',
#   'free',
#   'sample'],
#  ['lousy', 'cheap', 'country'],
#  ['bart', 'spirit', 'st', 'louis'],
#  ['oh', 'marge', 'grow'],
#  ['congressman', 'springfield', 'national', 'forest'],
#  ['basically', 'want', 'cut'],
#  ['artist',
#   'rendition',
#   'old',
#   'growth',
#   'age',
#   'festering',
#   'away',
#   'come',
#   'log',
#   'company',
#   'thin',
#   'clutter',
#   'nature',
#   'know',
#   'cycle'],
#  ['jerry',
#   'whale',
#   'lobbyist',
#   'like',
#   'logging',
#   'permit',
#   'uh',
#   'like',
#   'bury',
#   'toxic',
#   'waste',
#   'people',
#   'going',
#   'to',
#   'notice',
#   'tree',
#   'go'],
#  ['uh', 'congressman', 'get', 'awkward', 'know', 'want'],
#  ['offer', 'bribe'],
#  ['little', 'girl', 'springfield', 'write', 'essay', 'good', 'photo', 'op'],
#  ['uh', 'sure', 'fine'],
#  ['get', 'little', 'place', 'use', 'uh', 'matter', 'tonight'],
#  ['hi', 'lisa', 'simpson'],
#  ['lisa',
#   'doer',
#   'know',
#   'maybe',
#   'day',
#   'congressman',
#   'senator',
#   'woman',
#   'senator',
#   'know'],
#  ['tot', 'shot', 'play', 'stick'],
#  ['ah', 'nice', 'politician', 'care'],
#  ['lisa', 'contest', 'hour'],
#  ['excited', 'sleep', 'winifred', 'beecher', 'howe', 'memorial'],
#  ['early',
#   'crusader',
#   'woman',
#   'right',
#   'lead',
#   'floormop',
#   'rebellion',
#   'later',
#   'appear',
#   'highly',
#   'unpopular',
#   'cent',
#   'piece'],
#  ['okay', 'know', 'miss'],
#  ['iron', 'sheet', 'iron', 'inequity', 'labor', 'law', 'amen', 'sister'],
#  ['bob', 'stand', 'springfield', 'forest', 'logging', 'permit'],
#  ['let', 'way', 'jerry', 'tim', 'berrr'],
#  ['read', 'essay', 'believe', 'word'],
#  ['honest', 'abe', 'way'],
#  ['mr', 'lincoln', 'need', 'advice', 'well', 'country'],
#  ['good', 'time', 'buy', 'house'],
#  ['boy', 'brush', 'proper'],
#  ['look', 'good', 'moustache'],
#  ['try', 'usin', 'turpentine', 'jes', 'bad'],
#  ['mr', 'lincoln', 'lisa', 'simpson', 'problem'],
#  ['mr', 'jefferson', 'lisa', 'simpson', 'problem'],
#  ['know', 'problem', 'lincoln', 'memorial', 'crowded'],
#  ['come',
#   'blame',
#   'important',
#   'declaration',
#   'independence',
#   'louisiana',
#   'purchase',
#   'dumbwaiter'],
#  ['uh', 'maybe', 'go', 'catch', 'bad', 'time'],
#  ['rudy', 'man', 'miracle', 'worker'],
#  ['bart', 'ready', 'room', 'service'],
#  ['kill', 'remember', 'trip', 'expense', 'pay'],
#  ['deficit',
#   'rag',
#   'oh',
#   'yeah',
#   'deficit',
#   'rag',
#   'budget',
#   'gap',
#   'digit',
#   'drag',
#   'tellin',
#   'ya',
#   'deficit',
#   'mess',
#   'deficit',
#   'ra',
#   'thank'],
#  ['oh', 'guy', 'awful'],
#  ['know', 'honey', 'sit'],
#  ['welcome',
#   'award',
#   'luncheon',
#   'like',
#   'introduce',
#   'distinguished',
#   'judge',
#   'select',
#   'scholarship',
#   'winner'],
#  ['redskin',
#   'great',
#   'alonzo',
#   'flower',
#   'perennial',
#   'party',
#   'candidate',
#   'wilson',
#   'defarge',
#   'senate',
#   'page',
#   'brad',
#   'fletcher',
#   'skin',
#   'care',
#   'consultant',
#   'rowena',
#   'wealthy',
#   'gadabout',
#   'chilton',
#   'gaine'],
#  ['essayist', 'lisa', 'simpson', 'lisa', 'lisa'],
#  ['oh', 'lisa', 'simpson', 'read', 'essay'],
#  ['like', 'read', 'different', 'essay'],
#  ['city',
#   'washington',
#   'build',
#   'stagnant',
#   'swamp',
#   'year',
#   'ago',
#   'little',
#   'change',
#   'stank',
#   'stink',
#   'today',
#   'fetid',
#   'stench',
#   'corruption',
#   'hang',
#   'air'],
#  ['take',
#   'bribe',
#   'honorable',
#   'bob',
#   'arnold',
#   'worry',
#   'congressman',
#   'sure',
#   'you',
#   'vote',
#   'need',
#   'dirty',
#   'money',
#   'nation',
#   'dollar',
#   'liberty',
#   'justice'],
#  ['senator', 'problem', 'essay', 'contest'],
#  ['little', 'girl', 'lose', 'faith', 'democracy'],
#  ['congressman', 'want', 'drill', 'oil', 'teddy', 'roosevelt', 'head'],
#  ['work', 'uncle', 'sam'],
#  ['vote', 'house', 'bill', 'expulsion', 'bob', 'arnold'],
#  ['mr', 'speaker', 'bill', 'tack', 'pay', 'raise'],
#  ['okay', 'boss', 'happy'],
#  ['family',
#   'arrive',
#   'country',
#   'month',
#   'ago',
#   'speak',
#   'english',
#   'money',
#   'pocket',
#   'today',
#   'nationwide',
#   'chain',
#   'wheel',
#   'balancing',
#   'center',
#   'america',
#   'possibly',
#   'canada',
#   'family',
#   'find',
#   'opportunity',
#   'star',
#   'stripe',
#   'remind',
#   'wonderful',
#   'word',
#   'flag'],
#  ['brief', 'recess', 'judge', 'tabulate', 'vote'],
#  ['yeah', 'speech', 'little', 'crowd', 'pleasin'],
#  ['sorry', 'dad', 'think', 'nice', 'way', 'america', 'stink'],
#  ['extra', 'extra', 'fed', 'nab', 'rotten', 'rep'],
#  ['imprison', 'congressman', 'bear', 'christian'],
#  ['believe', 'system', 'work'],
#  ['trading',
#   'gap',
#   'shuffle',
#   'heap',
#   'trouble',
#   'doing',
#   'trading',
#   'gap',
#   'shuffle',
#   'yes',
#   'sir'],
#  ['budget', 'gap', 'trading', 'gap'],
#  ['moment',
#   'truth',
#   'win',
#   'essay',
#   'bubble',
#   'melting',
#   'pot',
#   'lift',
#   'high',
#   'lamp',
#   'green',
#   'lady',
#   'usa',
#   'cesspool',
#   'potomac'],
#  ['cesspool', 'cesspool', 'cesspool', 'cesspool', 'cesspool'],
#  ['winner', 'usa', 'truong', 'van', 'dinh'],
#  ['miss',
#   'crowley',
#   'thank',
#   'sized',
#   'novelty',
#   'check',
#   'like',
#   'share',
#   'honor',
#   'fellow',
#   'essayist',
#   'particularly',
#   'courageous',
#   'lisa',
#   'simpson',
#   'inflammatory',
#   'rhetoric',
#   'remind',
#   'price',
#   'freedom',
#   'eternal',
#   'vigilance'],
#  ['let',
#   'tell',
#   'lisa',
#   'little',
#   'year',
#   'old',
#   'muckraker',
#   'ess',
#   'catch',
#   'crook',
#   'pay',
#   'day',
#   'ball'],
#  ['lis', 'teach', 'stand', 'believe'],
#  ['homer', 'silly', 'goose', 'weed', 'whacker', 'edge', 'going', 'to', 'day'],
#  ['picture',
#   'half',
#   'hee',
#   'hee',
#   'finish',
#   'tomorrow',
#   'come',
#   'strap',
#   'feed',
#   'bag',
#   'going',
#   'to',
#   'fire',
#   'old',
#   'propane',
#   'elaine',
#   'heat',
#   'meat',
#   'nummy',
#   'nummy',
#   'num'],
#  ['flander',
#   'have',
#   'beef',
#   'thon',
#   'incredible',
#   'ned',
#   'ibles',
#   'maude',
#   'acious',
#   'vittle'],
#  ['think', 'mean', 'have', 'barbecue'],
#  ['try', 'friendly', 'know', 'give', 'ned', 'flander', 'chance'],
#  ['oh',
#   'look',
#   'care',
#   'ned',
#   'flander',
#   'nice',
#   'guy',
#   'world',
#   'jerk',
#   'end',
#   'story'],
#  ['hold', 'thing', 'little', 'well'],
#  ['excuse', 'well', 'thank', 'lot', 'marge', 'place'],
#  ['wrong',
#   'worth',
#   'feel',
#   'inch',
#   'tall',
#   'find',
#   'kind',
#   'person',
#   'marge',
#   'simpson',
#   'president',
#   'international',
#   'love',
#   'flander',
#   'fan',
#   'club'],
#  ['fee',
#   'fi',
#   'fo',
#   'fum',
#   'smell',
#   'potato',
#   'au',
#   'gratin',
#   'marge',
#   'simp',
#   'son',
#   'mmmm',
#   'mmm'],
#  ['hi',
#   'ned',
#   'homer',
#   'send',
#   'apology',
#   'uh',
#   'important',
#   'work',
#   'plant',
#   'care'],
#  ['return',
#   'exciting',
#   'fifteenth',
#   'round',
#   'action',
#   'canadian',
#   'football',
#   'league',
#   'draft'],
#  ['saskatchewan',
#   'rough',
#   'rider',
#   'score',
#   'rouge',
#   'season',
#   'jack',
#   'kicker',
#   'sorely',
#   'need'],
#  ['stupid',
#   'flander',
#   'show',
#   'ahead',
#   'marge',
#   'ball',
#   'game',
#   'dead',
#   'eat',
#   'cry',
#   'eye',
#   'go',
#   'flander',
#   'oh',
#   'flander',
#   'house',
#   'leave',
#   'homer',
#   'food',
#   'laugh',
#   'laugh',
#   'grave'],
#  ['boy', 'mmmmmmmm', 'bar', 'que'],
#  ['hey', 'great', 'ya', 'nice', 'seein', 'ya'],
#  ['okay', 'thank', 'comin'],
#  ['electricity', 'electricity', 'freeze', 'tag'],
#  ['lie', 'like', 'fly', 'booger', 'eye'],
#  ['fly', 'funny', 'booger', 'icing', 'cake'],
#  ['friend',
#   'love',
#   'sinister',
#   'motive',
#   'ask',
#   'sinister',
#   'latin',
#   'left',
#   'handed',
#   'joking'],
#  ['friday', 'say', 'toodle', 'oo', 'pharmaceutical', 'game'],
#  ['kid', 'noose', 'wear', 'year'],
#  ['sir',
#   'like',
#   'americans',
#   'leave',
#   'handed',
#   'let',
#   'tell',
#   'be',
#   'peach',
#   'cream',
#   'writing',
#   'get',
#   'smear',
#   'lord',
#   'help',
#   'want',
#   'drive',
#   'standard',
#   'transmission'],
#  ['sir',
#   'open',
#   'stop',
#   'store',
#   'southpaw',
#   'left',
#   'handed',
#   'apple',
#   'peeler',
#   'left',
#   'handed',
#   'zither',
#   'going',
#   'to',
#   'leftorium'],
#  ['homer', 'dyin', 'know', 'think', 'leftorium'],
#  ['uh', 'sound', 'like', 'pretty', 'dumb', 'idea'],
#  ['know',
#   'little',
#   'risky',
#   'going',
#   'to',
#   'lot',
#   'hard',
#   'work',
#   'gosh',
#   'darn',
#   'going',
#   'to',
#   'lot',
#   'fun'],
#  ['fun', 'store', 'flander', 'merry', 'old', 'land', 'oz'],
#  ['oh', 'springfield', 'mall'],
#  ['want', 'wish', 'homer'],
#  ['come', 'homer', 'get', 'ambition', 'wishin'],
#  ['pant', 'flander', 'wish', 'fast'],
#  ['yesssss', 'oh', 'yessss', 'read', 'weep', 'face', 'get', 'chicken', 'bone'],
#  ['will', 'come', 'true'],
#  ['bart', 'hour', 'day', 'watch', 'tv'],
#  ['think', 'little', 'fresh', 'air', 'maybe', 'exercise'],
#  ['yeah', 'ya', 'going', 'to'],
#  ['marge', 'tv', 'give', 'ask', 'little', 'boy', 'good', 'friend'],
#  ['problem',
#   'speak',
#   'million',
#   'child',
#   'stare',
#   'tv',
#   'instead',
#   'get',
#   'need',
#   'exercise',
#   'child',
#   'parent',
#   'ashamed'],
#  ['hello', 'akira', 'ha'],
#  ['hurt', 'know', 'ancient', 'art', 'karate'],
#  ['karate', 'focus', 'mind', 'give', 'self', 'confidence'],
#  ['people', 'walk', 'life', 'doctor'],
#  ['landscape', 'architect'],
#  ['high', 'karate', 'low', 'low', 'price'],
#  ['tell', 'lie', 'great', 'deal'],
#  ['hey', 'mom', 'bout', 'learn', 'karate', 'happy'],
#  ['sound', 'fine', 'bart'],
#  ['marge',
#   'knock',
#   'tv',
#   'help',
#   'think',
#   'owe',
#   'somebody',
#   'little',
#   'apology'],
#  ['ow', 'ow', 'ow', 'ow'],
#  ['hey', 'flander', 'business'],
#  ['oh', 'little', 'pokey', 'thing', 'going', 'to', 'pick'],
#  ['money', 'away', 'accident'],
#  ['thank', 'validate', 'parking'],
#  ['mall',
#   'security',
#   'guard',
#   'take',
#   'good',
#   'long',
#   'look',
#   'left',
#   'handed',
#   'ice',
#   'cream',
#   'scoop'],
#  ['greeting',
#   'akira',
#   'guide',
#   'path',
#   'true',
#   'karate',
#   'map',
#   'art',
#   'war',
#   'sun',
#   'tzu',
#   'teach',
#   'important',
#   'lesson',
#   'learn',
#   'karate',
#   'need',
#   'use'],
#  ['um', 'excuse', 'sir', 'know', 'hit', 'guy', 'break', 'nunchuck'],
#  ['ah', 'yes', 'impetuousness', 'youth', 'let', 'read'],
#  ['akira', 'good', 'man', 'break', 'block', 'ice', 'head'],
#  ['fill', 'head', 'wisdom', 'hit', 'ice'],
#  ['yo', 'sensei', 'bathroom'],
#  ['pay', 'money', 'read', 'book', 'hell'],
#  ['come', 'touch', 'death', 'touch', 'death', 'touch', 'death'],
#  ['tell',
#   'flander',
#   'store',
#   'dee',
#   'serte',
#   'think',
#   'best',
#   'buddy',
#   'marge'],
#  ['dad', 'know', 'schadenfreude'],
#  ['know', 'schadenfreude', 'tell', 'die', 'know'],
#  ['german', 'term', 'shameful', 'joy', 'take', 'pleasure', 'suffering'],
#  ['oh',
#   'come',
#   'lisa',
#   'glad',
#   'fall',
#   'flat',
#   'butt',
#   'you',
#   'happy',
#   'comfortable',
#   'surround',
#   'love',
#   'one',
#   'make',
#   'feel',
#   'opposite',
#   'shameful',
#   'joy',
#   'thing'],
#  ['boy', 'german', 'word'],
#  ['bart', 'learn', 'karate', 'school', 'today'],
#  ['yeah', 'come', 'boy', 'well', 'worth', 'buck'],
#  ['uh', 'learn', 'touch', 'death'],
#  ['ooh', 'touch', 'death'],
#  ['permit', 'demonstrate', 'lisa', 'shut', 'eye', 'soon', 'peace'],
#  ['hey', 'quit', 'bart', 'quit', 'hey', 'quit', 'quit', 'quit'],
#  ['bart', 'use', 'touch', 'death', 'sister'],
#  ['uh', 'oh', 'got', 'to', 'karate', 'class'],
#  ['right', 'comin', 'outta', 'way', 'step', 'aside', 'lady'],
#  ['hey', 'boy', 'class'],
#  ['today', 'learn', 'rip', 'man', 'heart', 'die'],
#  ['oh', 'learn'],
#  ['love', 'lefty', 'shoot', 'glass'],
#  ['leave', 'handed', 'pink', 'shear'],
#  ['pink', 'shear', 'let', 'food', 'court', 'steal', 'baked', 'potato'],
#  ['hey', 'flander', 'busy', 'hour'],
#  ['oh',
#   'oh',
#   'oh',
#   'expect',
#   'thing',
#   'start',
#   'pick',
#   'soon',
#   'think',
#   'word',
#   'mouth',
#   'startin',
#   'spread'],
#  ['hey', 'hear', 'validate', 'parking', 'ticket', 'purchase'],
#  ['oh', 'right', 'rain', 'leave', 'rain'],
#  ['hey', 'homer', 'neighbor', 'store'],
#  ['lousy', 'sit', 'day', 'great', 'job', 'place'],
#  ['crummy', 'right', 'hand', 'corkscrew', 'sell'],
#  ['uh', 'actually', 'moe'],
#  ['hey', 'li', 'change', 'channel'],
#  ['grow', 'weary', 'new', 'channel', 'change'],
#  ['apple',
#   'apple',
#   'apple',
#   'come',
#   'candy',
#   'bar',
#   'hey',
#   'know',
#   'apple',
#   'want',
#   'sink',
#   'going',
#   'to',
#   'let',
#   'em',
#   'time'],
#  ['simpson', 'box', 'mr', 'burns', 'desk', 'chop', 'chop'],
#  ['ah',
#   'look',
#   'smither',
#   'member',
#   'nuclear',
#   'family',
#   'helpful',
#   'suggestion'],
#  ['simpson', 'eh', 'hmm', 'hmmm', 'monty', 'burn'],
#  ['hm',
#   'handsome',
#   'owner',
#   'sight',
#   'distract',
#   'female',
#   'employee',
#   'smither'],
#  ['oh', 'real', 'apple', 'vend', 'machine', 'sentence'],
#  ['leave', 'mr', 'burn'],
#  ['oh', 'course', 'worry', 'plenty', 'apple', 'away', 'precious', 'apple'],
#  ['tell', 'secretary', 'say', 'free', 'apple', 'right', 'promise'],
#  ['damn', 'infernal', 'gizmo', 'kingdom', 'left', 'handed', 'opener'],
#  ['um', 'mr', 'burn'],
#  ['come', 'homer', 'tell', 'store', 'dyin'],
#  ['sure', 'interested', 'dollar', 'asking', 'price'],
#  ['hey', 'flexible', 'you', 'night', 'change', 'mind'],
#  ['hey', 'flander', 'okay'],
#  ['oh', 'yeah', 'sure', 'think', 'rid', 'clutter', 'like'],
#  ['oh', 'good', 'good', 'catch', 'dead', 'buy', 'hello'],
#  ['ah', 'get', 'eye', 'gas', 'grill', 'butane', 'beaut'],
#  ['homer', 'pay', 'dollar', 'year'],
#  ['swindle', 'friend', 'buck', 'leave'],
#  ['oh', 'homer', 'reasonable'],
#  ['sorry',
#   'cash',
#   'neddie',
#   'homer',
#   'money',
#   'bye',
#   'bye',
#   'neddie',
#   'bye',
#   'bye'],
#  ['change',
#   'mind',
#   'pass',
#   'fancy',
#   'throw',
#   'lawn',
#   'chair',
#   'maybe',
#   'tool',
#   'bench',
#   'rekindle',
#   'interest'],
#  ...]

# %%
#Creating relevant phrases from the list of sentences by using Gensim Phrases package
from gensim.models.phrases import Phrases, Phraser

# %%
phrases = Phrases(content, min_count=30, progress_per=10000)
# Out:
# INFO - 14:11:36: collecting all words and their counts
# INFO - 14:11:36: PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO - 14:11:36: PROGRESS: at sentence #10000, processed 63557 words and 52763 word types
# INFO - 14:11:36: PROGRESS: at sentence #20000, processed 130938 words and 99744 word types
# INFO - 14:11:36: PROGRESS: at sentence #30000, processed 192959 words and 138351 word types
# INFO - 14:11:37: PROGRESS: at sentence #40000, processed 249832 words and 172387 word types
# INFO - 14:11:37: PROGRESS: at sentence #50000, processed 311271 words and 208254 word types
# INFO - 14:11:37: PROGRESS: at sentence #60000, processed 373576 words and 243325 word types
# INFO - 14:11:37: PROGRESS: at sentence #70000, processed 436427 words and 278322 word types
# INFO - 14:11:37: PROGRESS: at sentence #80000, processed 497902 words and 311462 word types
# INFO - 14:11:37: collected 330189 token types (unigram + bigrams) from a corpus of 537083 words and 85952 sentences
# INFO - 14:11:37: merged Phrases<330189 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 14:11:37: Phrases lifecycle event {'msg': 'built Phrases<330189 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 1.69s', 'datetime': '2021-12-11T14:11:37.971676', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}

# %%
bigram = Phraser(phrases)
# Out:
# INFO - 14:11:39: exporting phrases from Phrases<330189 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# INFO - 14:11:40: FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<127 phrases, min_count=30, threshold=10.0> from Phrases<330189 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 1.79s', 'datetime': '2021-12-11T14:11:40.854033', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}

# %%
#Transform the corpus based on the  detected bigrams
sentences = bigram[content]

# %% [markdown]
# ## Building and training W2V Model:

# %%
import multiprocessing

from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer

# %%
w2v_model = Word2Vec(min_count=20,
                     window=2,
                     vector_size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
w2v_model.build_vocab(sentences, progress_per=10000)
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# INFO - 15:33:38: Word2Vec lifecycle event {'params': 'Word2Vec(vocab=0, vector_size=300, alpha=0.03)', 'datetime': '2021-12-11T15:33:38.701736', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# INFO - 15:33:38: collecting all words and their counts
# INFO - 15:33:38: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 15:33:38: PROGRESS: at sentence #10000, processed 61694 words, keeping 9501 word types
# INFO - 15:33:39: PROGRESS: at sentence #20000, processed 127310 words, keeping 14369 word types
# INFO - 15:33:39: PROGRESS: at sentence #30000, processed 187765 words, keeping 17424 word types
# INFO - 15:33:39: PROGRESS: at sentence #40000, processed 243261 words, keeping 20100 word types
# INFO - 15:33:39: PROGRESS: at sentence #50000, processed 303119 words, keeping 22539 word types
# INFO - 15:33:40: PROGRESS: at sentence #60000, processed 363855 words, keeping 24790 word types
# INFO - 15:33:40: PROGRESS: at sentence #70000, processed 425313 words, keeping 26965 word types
# INFO - 15:33:40: PROGRESS: at sentence #80000, processed 485446 words, keeping 28786 word types
# INFO - 15:33:41: collected 29651 word types from a corpus of 523523 raw words and 85952 sentences
# INFO - 15:33:41: Creating a fresh vocabulary
# INFO - 15:33:41: Word2Vec lifecycle event {'msg': 'effective_min_count=20 retains 3323 unique words (11.207041921014468%% of original 29651, drops 26328)', 'datetime': '2021-12-11T15:33:41.164361', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'prepare_vocab'}
# INFO - 15:33:41: Word2Vec lifecycle event {'msg': 'effective_min_count=20 leaves 437963 word corpus (83.6568784943546%% of original 523523, drops 85560)', 'datetime': '2021-12-11T15:33:41.168372', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'prepare_vocab'}
# INFO - 15:33:41: deleting the raw counts dictionary of 29651 items
# INFO - 15:33:41: sample=6e-05 downsamples 1205 most-common words
# INFO - 15:33:41: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 199488.08366748807 word corpus (45.5%% of prior 437963)', 'datetime': '2021-12-11T15:33:41.247314', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'prepare_vocab'}
# INFO - 15:33:41: estimated required memory for 3323 words and 300 dimensions: 9636700 bytes
# INFO - 15:33:41: resetting layer weights
# INFO - 15:33:41: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-12-11T15:33:41.392236', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'build_vocab'}
# INFO - 15:33:41: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 3323 vocabulary and 300 features, using sg=0 hs=0 sample=6e-05 negative=20 window=2 shrink_windows=True', 'datetime': '2021-12-11T15:33:41.393231', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'train'}
# INFO - 15:33:42: EPOCH 1 - PROGRESS: at 23.70% examples, 47262 words/s, in_qsize 3, out_qsize 1
# INFO - 15:33:43: EPOCH 1 - PROGRESS: at 41.55% examples, 40617 words/s, in_qsize 6, out_qsize 0
# INFO - 15:33:44: EPOCH 1 - PROGRESS: at 78.55% examples, 50117 words/s, in_qsize 4, out_qsize 1
# INFO - 15:33:44: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:44: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:44: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:44: EPOCH - 1 : training on 523523 raw words (199769 effective words) took 3.5s, 57189 effective words/s
# INFO - 15:33:45: EPOCH 2 - PROGRESS: at 25.71% examples, 50971 words/s, in_qsize 1, out_qsize 1
# INFO - 15:33:47: EPOCH 2 - PROGRESS: at 59.46% examples, 54288 words/s, in_qsize 4, out_qsize 0
# INFO - 15:33:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:48: EPOCH 2 - PROGRESS: at 100.00% examples, 62254 words/s, in_qsize 0, out_qsize 1
# INFO - 15:33:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:48: EPOCH - 2 : training on 523523 raw words (199280 effective words) took 3.2s, 62182 effective words/s
# INFO - 15:33:49: EPOCH 3 - PROGRESS: at 31.40% examples, 62180 words/s, in_qsize 1, out_qsize 0
# INFO - 15:33:50: EPOCH 3 - PROGRESS: at 61.37% examples, 56652 words/s, in_qsize 5, out_qsize 1
# INFO - 15:33:51: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:51: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:51: EPOCH - 3 : training on 523523 raw words (199116 effective words) took 3.0s, 66252 effective words/s
# INFO - 15:33:52: EPOCH 4 - PROGRESS: at 14.85% examples, 29465 words/s, in_qsize 5, out_qsize 0
# INFO - 15:33:53: EPOCH 4 - PROGRESS: at 53.72% examples, 51507 words/s, in_qsize 4, out_qsize 1
# INFO - 15:33:54: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:54: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:54: EPOCH - 4 : training on 523523 raw words (199473 effective words) took 3.0s, 67592 effective words/s
# INFO - 15:33:55: EPOCH 5 - PROGRESS: at 35.36% examples, 66495 words/s, in_qsize 5, out_qsize 0
# INFO - 15:33:56: EPOCH 5 - PROGRESS: at 78.55% examples, 74074 words/s, in_qsize 4, out_qsize 0
# INFO - 15:33:56: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:56: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:56: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:56: EPOCH - 5 : training on 523523 raw words (199781 effective words) took 2.6s, 77786 effective words/s
# INFO - 15:33:57: EPOCH 6 - PROGRESS: at 13.09% examples, 25492 words/s, in_qsize 5, out_qsize 0
# INFO - 15:33:58: EPOCH 6 - PROGRESS: at 49.87% examples, 48396 words/s, in_qsize 6, out_qsize 0
# INFO - 15:33:59: EPOCH 6 - PROGRESS: at 93.84% examples, 61010 words/s, in_qsize 4, out_qsize 0
# INFO - 15:33:59: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:33:59: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:33:59: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:33:59: EPOCH - 6 : training on 523523 raw words (199652 effective words) took 3.1s, 63388 effective words/s
# INFO - 15:34:00: EPOCH 7 - PROGRESS: at 33.38% examples, 63710 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:02: EPOCH 7 - PROGRESS: at 67.20% examples, 61721 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:02: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:02: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:03: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:03: EPOCH - 7 : training on 523523 raw words (199550 effective words) took 3.1s, 64540 effective words/s
# INFO - 15:34:04: EPOCH 8 - PROGRESS: at 27.50% examples, 55326 words/s, in_qsize 1, out_qsize 0
# INFO - 15:34:05: EPOCH 8 - PROGRESS: at 55.70% examples, 54138 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:06: EPOCH 8 - PROGRESS: at 78.48% examples, 51244 words/s, in_qsize 3, out_qsize 0
# INFO - 15:34:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:06: EPOCH - 8 : training on 523523 raw words (199577 effective words) took 3.5s, 57228 effective words/s
# INFO - 15:34:07: EPOCH 9 - PROGRESS: at 27.52% examples, 45361 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:09: EPOCH 9 - PROGRESS: at 69.10% examples, 54722 words/s, in_qsize 2, out_qsize 2
# INFO - 15:34:09: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:09: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:09: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:09: EPOCH - 9 : training on 523523 raw words (199454 effective words) took 3.2s, 62172 effective words/s
# INFO - 15:34:10: EPOCH 10 - PROGRESS: at 31.40% examples, 60516 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:11: EPOCH 10 - PROGRESS: at 61.47% examples, 58333 words/s, in_qsize 2, out_qsize 0
# INFO - 15:34:12: EPOCH 10 - PROGRESS: at 97.47% examples, 62948 words/s, in_qsize 2, out_qsize 1
# INFO - 15:34:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:12: EPOCH - 10 : training on 523523 raw words (199092 effective words) took 3.1s, 64357 effective words/s
# INFO - 15:34:14: EPOCH 11 - PROGRESS: at 21.91% examples, 41479 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:15: EPOCH 11 - PROGRESS: at 39.40% examples, 37644 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:16: EPOCH 11 - PROGRESS: at 69.10% examples, 43586 words/s, in_qsize 6, out_qsize 2
# INFO - 15:34:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:16: EPOCH - 11 : training on 523523 raw words (199457 effective words) took 3.7s, 54522 effective words/s
# INFO - 15:34:17: EPOCH 12 - PROGRESS: at 23.76% examples, 46959 words/s, in_qsize 2, out_qsize 0
# INFO - 15:34:18: EPOCH 12 - PROGRESS: at 55.70% examples, 53684 words/s, in_qsize 2, out_qsize 0
# INFO - 15:34:19: EPOCH 12 - PROGRESS: at 90.04% examples, 57478 words/s, in_qsize 0, out_qsize 2
# INFO - 15:34:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:19: EPOCH - 12 : training on 523523 raw words (199666 effective words) took 3.3s, 60825 effective words/s
# INFO - 15:34:20: EPOCH 13 - PROGRESS: at 31.40% examples, 64090 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:21: EPOCH 13 - PROGRESS: at 67.20% examples, 65173 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:22: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:22: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:22: EPOCH 13 - PROGRESS: at 100.00% examples, 65097 words/s, in_qsize 0, out_qsize 1
# INFO - 15:34:22: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:22: EPOCH - 13 : training on 523523 raw words (199500 effective words) took 3.1s, 65052 effective words/s
# INFO - 15:34:24: EPOCH 14 - PROGRESS: at 29.43% examples, 57783 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:25: EPOCH 14 - PROGRESS: at 70.98% examples, 66962 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:25: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:25: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:25: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:25: EPOCH - 14 : training on 523523 raw words (199581 effective words) took 2.7s, 75071 effective words/s
# INFO - 15:34:26: EPOCH 15 - PROGRESS: at 33.38% examples, 66527 words/s, in_qsize 1, out_qsize 0
# INFO - 15:34:27: EPOCH 15 - PROGRESS: at 72.86% examples, 67243 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:28: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:28: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:28: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:28: EPOCH - 15 : training on 523523 raw words (199472 effective words) took 2.6s, 77106 effective words/s
# INFO - 15:34:29: EPOCH 16 - PROGRESS: at 16.63% examples, 32886 words/s, in_qsize 3, out_qsize 1
# INFO - 15:34:30: EPOCH 16 - PROGRESS: at 57.56% examples, 55016 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:31: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:31: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:31: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:31: EPOCH - 16 : training on 523523 raw words (199536 effective words) took 3.0s, 66561 effective words/s
# INFO - 15:34:32: EPOCH 17 - PROGRESS: at 25.71% examples, 52795 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:33: EPOCH 17 - PROGRESS: at 65.23% examples, 63504 words/s, in_qsize 1, out_qsize 0
# INFO - 15:34:34: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:34: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:34: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:34: EPOCH - 17 : training on 523523 raw words (199796 effective words) took 2.9s, 68730 effective words/s
# INFO - 15:34:35: EPOCH 18 - PROGRESS: at 37.42% examples, 73528 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:36: EPOCH 18 - PROGRESS: at 55.70% examples, 53366 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:37: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:37: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:37: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:37: EPOCH - 18 : training on 523523 raw words (199403 effective words) took 3.1s, 65368 effective words/s
# INFO - 15:34:38: EPOCH 19 - PROGRESS: at 27.50% examples, 56225 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:39: EPOCH 19 - PROGRESS: at 69.08% examples, 67567 words/s, in_qsize 4, out_qsize 1
# INFO - 15:34:39: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:39: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:39: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:39: EPOCH - 19 : training on 523523 raw words (199733 effective words) took 2.6s, 78261 effective words/s
# INFO - 15:34:40: EPOCH 20 - PROGRESS: at 31.45% examples, 60530 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:41: EPOCH 20 - PROGRESS: at 59.46% examples, 55874 words/s, in_qsize 4, out_qsize 1
# INFO - 15:34:42: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:42: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:42: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:42: EPOCH - 20 : training on 523523 raw words (199524 effective words) took 2.9s, 68028 effective words/s
# INFO - 15:34:43: EPOCH 21 - PROGRESS: at 27.50% examples, 56383 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:44: EPOCH 21 - PROGRESS: at 69.07% examples, 67937 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:45: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:45: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:45: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:45: EPOCH - 21 : training on 523523 raw words (199248 effective words) took 2.6s, 75471 effective words/s
# INFO - 15:34:46: EPOCH 22 - PROGRESS: at 29.43% examples, 59131 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:47: EPOCH 22 - PROGRESS: at 59.46% examples, 53350 words/s, in_qsize 4, out_qsize 1
# INFO - 15:34:48: EPOCH 22 - PROGRESS: at 96.36% examples, 59664 words/s, in_qsize 2, out_qsize 1
# INFO - 15:34:48: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:48: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:48: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:48: EPOCH - 22 : training on 523523 raw words (199297 effective words) took 3.3s, 61105 effective words/s
# INFO - 15:34:49: EPOCH 23 - PROGRESS: at 31.40% examples, 63959 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:50: EPOCH 23 - PROGRESS: at 70.98% examples, 68462 words/s, in_qsize 0, out_qsize 0
# INFO - 15:34:51: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:51: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:51: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:51: EPOCH - 23 : training on 523523 raw words (199299 effective words) took 2.7s, 73702 effective words/s
# INFO - 15:34:52: EPOCH 24 - PROGRESS: at 29.43% examples, 57510 words/s, in_qsize 5, out_qsize 0
# INFO - 15:34:53: EPOCH 24 - PROGRESS: at 65.29% examples, 62311 words/s, in_qsize 6, out_qsize 0
# INFO - 15:34:54: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:54: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:54: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:54: EPOCH - 24 : training on 523523 raw words (199251 effective words) took 2.8s, 70694 effective words/s
# INFO - 15:34:55: EPOCH 25 - PROGRESS: at 31.40% examples, 61982 words/s, in_qsize 1, out_qsize 0
# INFO - 15:34:56: EPOCH 25 - PROGRESS: at 47.90% examples, 46427 words/s, in_qsize 3, out_qsize 1
# INFO - 15:34:57: EPOCH 25 - PROGRESS: at 78.48% examples, 51318 words/s, in_qsize 3, out_qsize 1
# INFO - 15:34:57: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:34:57: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:34:57: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:34:57: EPOCH - 25 : training on 523523 raw words (199356 effective words) took 3.5s, 57364 effective words/s
# INFO - 15:34:58: EPOCH 26 - PROGRESS: at 22.09% examples, 43238 words/s, in_qsize 1, out_qsize 0
# INFO - 15:35:00: EPOCH 26 - PROGRESS: at 55.58% examples, 51486 words/s, in_qsize 5, out_qsize 0
# INFO - 15:35:00: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:35:00: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:35:01: EPOCH 26 - PROGRESS: at 100.00% examples, 63234 words/s, in_qsize 0, out_qsize 1
# INFO - 15:35:01: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:35:01: EPOCH - 26 : training on 523523 raw words (199610 effective words) took 3.2s, 63140 effective words/s
# INFO - 15:35:02: EPOCH 27 - PROGRESS: at 23.76% examples, 47508 words/s, in_qsize 0, out_qsize 1
# INFO - 15:35:03: EPOCH 27 - PROGRESS: at 55.70% examples, 53685 words/s, in_qsize 0, out_qsize 0
# INFO - 15:35:04: EPOCH 27 - PROGRESS: at 82.31% examples, 53612 words/s, in_qsize 0, out_qsize 0
# INFO - 15:35:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:35:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:35:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:35:04: EPOCH - 27 : training on 523523 raw words (199494 effective words) took 3.6s, 55022 effective words/s
# INFO - 15:35:05: EPOCH 28 - PROGRESS: at 27.50% examples, 55609 words/s, in_qsize 0, out_qsize 0
# INFO - 15:35:06: EPOCH 28 - PROGRESS: at 43.69% examples, 42672 words/s, in_qsize 2, out_qsize 0
# INFO - 15:35:07: EPOCH 28 - PROGRESS: at 88.14% examples, 56065 words/s, in_qsize 0, out_qsize 1
# INFO - 15:35:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:35:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:35:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:35:08: EPOCH - 28 : training on 523523 raw words (199786 effective words) took 3.4s, 58801 effective words/s
# INFO - 15:35:09: EPOCH 29 - PROGRESS: at 25.55% examples, 52378 words/s, in_qsize 5, out_qsize 0
# INFO - 15:35:10: EPOCH 29 - PROGRESS: at 59.46% examples, 57796 words/s, in_qsize 5, out_qsize 0
# INFO - 15:35:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:35:11: EPOCH 29 - PROGRESS: at 98.13% examples, 64104 words/s, in_qsize 1, out_qsize 1
# INFO - 15:35:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:35:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:35:11: EPOCH - 29 : training on 523523 raw words (199716 effective words) took 3.1s, 65033 effective words/s
# INFO - 15:35:12: EPOCH 30 - PROGRESS: at 27.50% examples, 55078 words/s, in_qsize 5, out_qsize 0
# INFO - 15:35:13: EPOCH 30 - PROGRESS: at 55.70% examples, 52845 words/s, in_qsize 6, out_qsize 0
# INFO - 15:35:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 15:35:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 15:35:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 15:35:14: EPOCH - 30 : training on 523523 raw words (198973 effective words) took 3.0s, 66816 effective words/s
# INFO - 15:35:14: Word2Vec lifecycle event {'msg': 'training on 15705690 raw words (5984442 effective words) took 92.8s, 64479 effective words/s', 'datetime': '2021-12-11T15:35:14.206868', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'train'}
# (5984442, 15705690)

# %% [markdown]
# ## Exploring The Model:

# %% [markdown]
# ## 1.	Getting term index:

# %%
w2v_model.wv['woman'].shape
# Out:
# (300,)

# %%
w2v_model.wv.get_index('love')
# Out:
# 26

# %%
import numpy as np
np.sum(w2v_model.wv[w2v_model.wv.get_index('love') ] != w2v_model.wv['love'])
# Out:
# 0

# %%
w2v_model.wv.index_to_key[30]
# Out:
# 'need'

# %%
w2v_model.wv.has_index_for('abracadabra'), w2v_model.wv.has_index_for('love')
# Out:
# (False, True)

# %%
w2v_model.wv.cosine_similarities(w2v_model.wv['television'], w2v_model.wv.vectors).shape
# Out:
# (3323,)

# %% [markdown]
# ## 2.	Finding the most similar words to specific word:

# %%
w2v_model.wv.most_similar(positive=["maggie"])
# Out:
# [('awww', 0.6959978342056274),
#  ('lisa', 0.6897205710411072),
#  ('diaper', 0.6832014918327332),
#  ('mommy', 0.6822347044944763),
#  ('honey', 0.6789132356643677),
#  ('baby', 0.6729987263679504),
#  ('asleep', 0.668789803981781),
#  ('sweetie', 0.6681798696517944),
#  ('strangle', 0.6657243967056274),
#  ('babysitter', 0.6609887480735779)]

# %%
w2v_model.wv.most_similar(positive=["homer_simpson"])
# Out:
# [('pleased', 0.6862821578979492),
#  ('congratulation', 0.6820638179779053),
#  ('recent', 0.6686651706695557),
#  ('select', 0.6625051498413086),
#  ('speaker', 0.6583868265151978),
#  ('easily', 0.657917320728302),
#  ('waylon', 0.6530686020851135),
#  ('montgomery_burn', 0.642357349395752),
#  ('governor', 0.6418781876564026),
#  ('united_states', 0.6395424604415894)]

# %%
w2v_model.wv.most_similar(positive=["bart"])
# Out:
# [('lisa', 0.8351496458053589),
#  ('mom', 0.7507618069648743),
#  ('strangle', 0.7376942038536072),
#  ('hearing', 0.7370407581329346),
#  ('babysitter', 0.7178239822387695),
#  ('mom_dad', 0.71009761095047),
#  ('grownup', 0.7027170062065125),
#  ('homework', 0.7025983929634094),
#  ('badly', 0.6985287070274353),
#  ('creepy', 0.6970906257629395)]

# %%
w2v_model.wv.most_similar(positive = ['enemy'],topn=10 )
# Out:
# [('capture', 0.6891812086105347),
#  ('powerful', 0.6724203824996948),
#  ('ancient', 0.6638416051864624),
#  ('lead', 0.6283242702484131),
#  ('culture', 0.6201581358909607),
#  ('ben', 0.6042076349258423),
#  ('roman', 0.6034662127494812),
#  ('springfielder', 0.6022446155548096),
#  ('rare', 0.5997748374938965),
#  ('appear', 0.5927237272262573)]

# %%
w2v_model.wv.most_similar(positive = ['bush'],topn=10 )
# Out:
# [('washington', 0.8255041241645813),
#  ('george', 0.8212107419967651),
#  ('clinton', 0.7739414572715759),
#  ('w', 0.7218510508537292),
#  ('smith', 0.7072834968566895),
#  ('president', 0.7069959044456482),
#  ('pope', 0.675169050693512),
#  ('kennedy', 0.6705697178840637),
#  ('neighborhood', 0.6596847772598267),
#  ('dean', 0.6257457733154297)]

# %%
from sklearn.preprocessing import normalize

v = normalize(w2v_model.wv['man'].reshape(1,-1))  \
    - normalize(w2v_model.wv['woman'].reshape(1,-1)) \
    + normalize(w2v_model.wv['king'].reshape(1,-1))

[(key, sim) for key, sim in w2v_model.wv.most_similar(v) if key not in ['king', 'men', 'women']] # remove source words
# Out:
# [('man', 0.5787461996078491),
#  ('sprinkle', 0.5294414162635803),
#  ('jolly', 0.4946066737174988),
#  ('aisle', 0.4904380440711975),
#  ('knight', 0.47524911165237427),
#  ('se', 0.466854989528656),
#  ('france', 0.46579408645629883),
#  ('barrel', 0.4623803496360779),
#  ('crown', 0.45758697390556335)]

# %% [markdown]
# ## 3.	How similar are two words to each other :

# %%
w2v_model.wv.similarity('maggie', 'awww')
# Out:
# 0.72678053

# %%
w2v_model.wv.similarity("moe", 'tavern')
# Out:
# 0.86759853

# %%
w2v_model.wv.similarity('homer', 'marge')
# Out:
# 0.7433727

# %%
w2v_model.wv.similarity('bart', 'nelson')
# Out:
# 0.54328275

# %% [markdown]
# ##  4.	Closer than (odd):

# %%
w2v_model.wv.doesnt_match(["nelson", "bart", "milhouse"])
# Out:
# 'nelson'

# %%
w2v_model.wv.doesnt_match(['homer', 'patty', 'selma'])
# Out:
# 'homer'

# %%
w2v_model.wv.doesnt_match(['cat', 'dog', 'chicken', 'lion'])
# Out:
# 'chicken'

# %%
w2v_model.wv.doesnt_match(['bush', 'clinton', 'kennedy', 'pope'])
# Out:
# 'pope'

# %%
w2v_model.wv.doesnt_match(['window', 'door', 'chair','cat'])
# Out:
# 'cat'

# %% [markdown]
# ## 5.	Most  similar words to another related couple of words:

# %%
w2v_model.wv.most_similar(positive=["woman", "homer"], negative=["marge"], topn=4)
# Out:
# [('married', 0.6111018657684326),
#  ('man', 0.5843933820724487),
#  ('admire', 0.5635032653808594),
#  ('boyfriend', 0.5424638390541077)]

# %%
w2v_model.wv.most_similar(positive=["woman", "bart"], negative=["man"], topn=3)
# Out:
# [('lisa', 0.7200313806533813),
#  ('pregnant', 0.6605644226074219),
#  ('parent', 0.6503780484199524)]

# %%
w2v_model.wv.most_similar(positive = ['king', 'woman'], negative=['man'],topn=10 )
# Out:
# [('queen', 0.5765933394432068),
#  ('arthur', 0.5398191809654236),
#  ('critic', 0.5121352076530457),
#  ('david', 0.5054819583892822),
#  ('plow', 0.5037469863891602),
#  ('nonsense', 0.49150320887565613),
#  ('coincidence', 0.4874555170536041),
#  ('larry', 0.48521852493286133),
#  ('simon', 0.47430115938186646),
#  ('disturb', 0.46996352076530457)]

# %% [markdown]
# ## 6.	closer_than (key1, key2):
# Get all keys that are closer to key1 than key2 is to key1

# %%
w2v_model.wv.closer_than('hope', 'wish')
# Out:
# ['feeling',
#  'decision',
#  'relationship',
#  'rest_life',
#  'decent',
#  'sacrifice',
#  'humiliate',
#  'babysitter',
#  'arrange',
#  'grownup',
#  'embarrassing',
#  'adopt',
#  'awake',
#  'bribe',
#  'eliza',
#  'haunt',
#  'anyhoo',
#  'exploit',
#  'badly']

# %% [markdown]
# ## 7.Compute distance between terms:

# %%
w2v_model.wv.distance('dog', 'cat'), w2v_model.wv.distance('cool', 'amazing'),  w2v_model.wv.distance('car', 'truck')
# Out:
# (0.2969825267791748, 0.7218841314315796, 0.3452696204185486)

# %%
distances = w2v_model.wv.distances('america') # distance to all words
[model.wv.index_to_key[key] for key in np.argsort(distances)[:10]]
# Out:
# ['america',
#  'nearly',
#  'hopeless',
#  'pure',
#  'shh',
#  'suggestion',
#  'bulletin',
#  'sh',
#  'punishment',
#  'discipline']
